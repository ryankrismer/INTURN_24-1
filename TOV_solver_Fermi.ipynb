# %% [markdown]
# # TOV Solver

# %% [markdown]
# # (X) Old discontinued code

# %% [markdown]
# ### (X) Original TOV test: non-interacting pure neutron Fermi gas, relativistic EoS (does not produce good plots)

# %%
# # r = distance from center
# # m = cumulative mass enclosed within distance r from center
# # p = pressure at distance r from center
# # epsilon = energy density at distance r from center

# # TOV simplified for relativistic pure neutron Fermi gas EoS, epsilon = 3 * p
# # Later will generalize TOV by adding gamma polytrope exponent and K EoS constant as parameters
# # Generalized EoS: p = K * epsilon ** gamma (right now gamma = 1 and K = 1/3)

# # TOV coded to be compatible w/ cgs units, but can't explicitly give units in code b/c solve_ivp() throws errors

# def TOV(r, p_and_m):
#     p = p_and_m[0]
#     m = p_and_m[1]
#     p_result = - G * (4 * p) * m / c ** 2 / r ** 2 * (1 + 4 * pi * r ** 3 * p / m / c ** 2) * (1 - 2 * G * m / c ** 2 / r) ** (-1)
#     m_result = 12 * pi * r ** 2 * p / c ** 2
#     return [p_result, m_result]

# %% [markdown]
# ### (X) Original EoS: relativistic pure neutron Fermi gas, does not make good plots

# %%
# Original EoS: relativistic pure neutron Fermi gas
# (does not make good plots):

# def p_from_rho(rho):
#     result = c ** 2 * rho / 3
#     return result

# p_central = p_from_rho(rho_central)

# %% [markdown]
# ## (X) Initial relativistic pure neutron Fermi gas EoS attempt

# %% [markdown]
# ### Original solve_ivp() attempt, bad plots

# %%
# solution = solve_ivp(TOV,
#                      [small_r, R_attempt],
#                      [p_central, m_central])

# %%
# cumulative_mass = solution.y[1] * u.g
# cumulative_mass = cumulative_mass.to(u.solMass)
# cumulative_mass

# %%
# pressure = solution.y[0]
# pressure

# %%
# distance_from_center = solution.t * u.cm
# distance_from_center = distance_from_center.to(u.km)
# distance_from_center

# %% [markdown]
# ### Plots of cumulative mass and pressure vs distance from center

# %%
# fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 8))

# ax1.plot(distance_from_center, cumulative_mass);
# ax2.plot(distance_from_center, pressure);

# %% [markdown]
# ### Now iterating over many radii and central mass densities

# %%
# rho_central_initial = 10 ** 14

# rho_central = rho_central_initial
# rho_central_step = 10 ** 14

# mass = []
# radius = []

# while rho_central <= 100 * rho_central_initial:

#     R_initial = 10 ** 5

#     R = R_initial
#     r_step = 10 ** 5

#     p_central = p_from_rho(rho_central)
#     m_central = M_from_r_and_rho(small_r, rho_central)
    
#     while R <= 60 * R_initial:
    
#         solution = solve_ivp(TOV,
#                              [small_r, R],
#                              [p_central, m_central])

#         cumulative_mass = (solution.y[1] * u.g).to(u.solMass)
    
#         mass.append(cumulative_mass[-1])
#         radius.append(R)
    
#         R += r_step

#     rho_central += rho_central_step

# %%
# mass = (mass * u.g).to(u.solMass)
# radius = (radius * u.cm).to(u.km)

# %%
# fig, ax = plt.subplots(figsize = (8, 8))

# ax.plot(radius, mass, markersize = 0.5, marker = "o", linestyle = "None");

# %% [markdown]
# ### Trying odeint() instead of solve_ivp()

# %%
# distance_from_center = np.arange(small_r, R_attempt, small_r)

# solution = odeint(TOV,
#                   t = distance_from_center,
#                   y0 = [p_central, m_central],
#                   tfirst = True)

# %%
# distance_from_center = (distance_from_center * u.cm).to(u.km)

# %%
# cumulative_mass = solution[:, 1] * u.g
# cumulative_mass = cumulative_mass.to(u.solMass)
# # cumulative_mass

# %%
# pressure = solution[:, 0]
# #pressure

# %%
# fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 8))

# ax1.plot(distance_from_center, cumulative_mass);
# ax2.plot(distance_from_center, pressure);

# %% [markdown]
# ## (X) My EoS attempt

# %%
# r = distance from center
# m = cumulative mass enclosed within distance r from center
# p = pressure at distance r from center
# epsilon = energy density at distance r from center

# TOV and EoS coded to be compatible w/ cgs units, but can't explicitly give units in code b/c solve_ivp() throws errors
# Will input A and gamma and epsilon_0 using args paramter for odeint()

# TOV generalized for arbitrary relativity
# A_NR = EoS coefficient for non-relativistic case
# gamma_NR = EoS polytrope exponent for non-relativistic case
# A_R = EoS coefficient for relativistic case
# gamma_R = EoS polytrope exponent for relativistic case
# epsilon_0 = additional EoS coefficient for arbitrary relativity

# A = weight of non-relativistic case relative to relativistic case

# def TOV(r, p_and_m, K_NR, gamma_NR, K_R, gamma_R, A):
#     p = p_and_m[0]
#     m = p_and_m[1]
#     epsilon = A * (p / K_NR) ** (1 / gamma_NR) + (1 - A) * (p / K_R) ** (1 / gamma_R)
#     p_result = - G * epsilon * m / c ** 2 / r ** 2 * (1 + p / epsilon) * (1 + 4 * pi * r ** 3 * p / m / c ** 2) * (1 - 2 * G * m / c ** 2 / r) ** (-1)
#     m_result = 12 * pi * r ** 2 * p / c ** 2
#     return [p_result, m_result]

# %%
# EoS coded to be compatible w/ cgs units, but can't explicitly give units in code b/c solve_ivp() throws errors

# Arbitrary relativity EoS

# def EoS_minus_rho(p, A, K_NR, gamma_NR, K_R, gamma_R, rho): # mass density minus rho
#     result = 1 / c ** 2 * (A * (p / K_NR) ** (1 / gamma_NR) + (1 - A) * (p / K_R) ** (1 / gamma_R)) - rho
#     return result

# %%
# def p_from_EoS(rho, K_NR, gamma_NR, K_R, gamma_R, A):
#     # p_test = 1
#     # rho_test = rho_from_EoS(A, p_test, K_NR, gamma_NR, K_R, gamma_R)

#     result = optimize.brentq(EoS_minus_rho,
#                              0,
#                              10 ** 40,
#                              args = (A, K_NR, gamma_NR, K_R, gamma_R, rho))
#     while not math.isclose(rho_test, rho, rel_tol = 10 ** (-4)):
#     rho_test = rho_from_EoS(A, p_test, K_NR, gamma_NR, K_R, gamma_R)
#     p_test += K_R * (c ** 2 * rho) ** gamma_R / 10 ** 5

#     print(f"Reached this point, w/ rho_test = {rho_test:.2e}")
#     result = p_test

# %%
# This should be the only cell that is changed for different EoS

# Non-relativisitc and relativistic EoS for non-interacting pure
# neutron Fermi gas

# gamma_NR = 5 / 3
# gamma_R = 1
# K_NR = 6.483 * 10 ** (-26) # From Sanjay's paper, cgs
# K_R = 1 / 3 # cgs
# A = 0.0446 # Found from Sanjay's paper and Desmos

# p_central = p_from_EoS(rho_central, K_NR, gamma_NR, K_R, gamma_R, A)


# Central pressure for simple polytropic EoS

# p_central = p_from_simp_poly_EoS(rho_central, K_NR, gamma_NR)

# %%
# Keep this for all EoS

# distance_from_center = np.arange(small_r, R_attempt, small_r)

# solution = odeint(TOV,
#                   t = distance_from_center,
#                   y0 = [p_central, m_central],
#                   tfirst = True,
#                   args = (K_NR, gamma_NR, K_R, gamma_R, A))

# %%
# Iterating with lower resolution

# rho_central_initial = 1.0 * 10 ** 11
# mass = []
# radius = []
# pressure_list = []
# mass_density = []

# rho_central = rho_central_initial
# rho_central_step = rho_central
# rho_central_max = 1.0 * 10 ** 3 * rho_central

# while rho_central <= 1000 * rho_central_initial:

#     p_central = p_from_EoS(rho_central, K_NR, gamma_NR, K_R, gamma_R, A)
#     print("Reached this point")
#     m_central = M_from_r_and_rho(small_r, rho_central)

#     distance_from_center = np.arange(small_r, R_attempt, small_r)
    
#     solution = odeint(TOV,
#                       t = distance_from_center,
#                       y0 = [p_central, m_central],
#                       tfirst = True,
#                       args = (K_NR, gamma_NR, K_R, gamma_R, A))

#     distance_from_center = (distance_from_center * u.cm).to(u.km)
#     cumulative_mass = (solution[:, 1] * u.g).to(u.solMass)
#     pressure = solution[:, 0]
    
#     # fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (1, 0.5))

#     # ax1.plot(distance_from_center, cumulative_mass);
#     # ax2.plot(distance_from_center, pressure);

#     # Removing NaN and inf values from cumulative mass

#     cumulative_mass = cumulative_mass[~np.isnan(cumulative_mass)]
#     cumulative_mass = cumulative_mass[~np.isinf(cumulative_mass)]
    
#     max_cumulative_mass = np.max(cumulative_mass)
#     index = np.where(cumulative_mass == max_cumulative_mass)
#     mass.append(np.max(cumulative_mass.value))
#     radius.append(distance_from_center[index][-1].value)

#     rho_central += rho_central_step

# Iterating with intermediate resolution
  
# rho_central_step *= 10 ** 3
# rho_central_max *= 10 ** 3

# %% [markdown]
# ## (X) Long-winded iterating over central mass densities

# %%
# rho_central_initial = 1.0 * 10 ** 11
# rho_central = rho_central_initial
# rho_central_step = rho_central
# rho_central_max = 1.0 * 10 ** 3 * rho_central

# for i in range(3):
#     while rho_central <= rho_central_max:
    
#         p_central = p_from_EoS(rho_central, gamma_NR, gamma_R, A_NR, A_R, epsilon_0)
#         print("Reached this point")
#         m_central = M_from_r_and_rho(small_r, rho_central)
    
#         distance_from_center = np.arange(small_r, R_attempt, small_r)
        
#         solution = odeint(TOV,
#                           t = distance_from_center,
#                           y0 = [p_central, m_central],
#                           tfirst = True,
#                           args = (gamma_NR, gamma_R, A_NR, A_R, epsilon_0))
    
#         distance_from_center = (distance_from_center * u.cm).to(u.km)
#         cumulative_mass = (solution[:, 1] * u.g).to(u.solMass)
#         pressure = solution[:, 0]
        
#         # fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (1, 0.5))
    
#         # ax1.plot(distance_from_center, cumulative_mass);
#         # ax2.plot(distance_from_center, pressure);
    
#         # Removing NaN and inf values from cumulative mass
    
#         cumulative_mass = cumulative_mass[~np.isnan(cumulative_mass)]
#         cumulative_mass = cumulative_mass[~np.isinf(cumulative_mass)]
        
#         max_cumulative_mass = np.max(cumulative_mass)
#         index = np.where(cumulative_mass == max_cumulative_mass)
#         mass.append(max_cumulative_mass.value)
#         radius.append(distance_from_center[index][-1].value)
#         mass_density.append(rho_central)
#         pressure_list.append(pressure[0])
    
#         rho_central += rho_central_step

#     rho_central_step *= 10 ** 3
#     rho_central_max *= 10 ** 3

# %% [markdown]
# ## (X) Solving TOV: odeint() and solve_ivp()

# %%
# m_central = M_from_r_and_rho(small_r, rho_central)
# Central pressure for arbitrary relativity EoS
# p_central = p_from_EoS(rho_central, gamma_NR, gamma_R, A_NR, A_R, epsilon_0)

# odeint() method:

# distance_from_center = np.arange(small_r, R_attempt, small_r)

# solution = odeint(TOV,
#                   t = distance_from_center,
#                   y0 = [p_central, m_central],
#                   tfirst = True,
#                   args = (gamma_NR, gamma_R, A_NR, A_R, epsilon_0))


# solve_ivp() method:
# solution = solve_ivp(TOV,
#                      [small_r, R_attempt],
#                      [p_central, m_central],
#                      args = (gamma_NR, gamma_R, A_NR, A_R, epsilon_0))

# %%
# odeint() method:
# distance_from_center = (distance_from_center * u.cm).to(u.km)


# solve_ivp() method:
# distance_from_center = (solution.t * u.cm).to(u.km)

# %%
# odeint() method:
# cumulative_mass = (solution[:, 1] * u.g).to(u.solMass)


# solve_ivp() method:
# cumulative_mass = (solution.y[1] * u.g).to(u.solMass)

# %%
# odeint() method:
# pressure = solution[:, 0]


# solve_ivp() method:
# pressure = solution.y[0]

# %%
# m_central = M_from_r_and_rho(small_r, rho_central)
# p_central = p_from_EoS(rho_central[i], gamma_NR, gamma_R, A_NR, A_R, epsilon_0)

    # distance_from_center = np.arange(small_r, R_attempt, small_r)
    
    # solution = odeint(TOV,
    #                   t = distance_from_center,
    #                   y0 = [p_central, m_central[i]],
    #                   tfirst = True,
    #                   args = (gamma_NR, gamma_R, A_NR, A_R, epsilon_0))
    
    # distance_from_center = (distance_from_center * u.cm).to(u.km)
    # cumulative_mass = (solution[:, 1] * u.g).to(u.solMass)
    # pressure = solution[:, 0]

# %%
# This should be the only cell that is changed for different EoS

# Non-relativisitc and relativistic EoS for non-interacting pure
# neutron Fermi gas

# gamma_NR = 5 / 3
# gamma_R = 1
# A_NR = 2.4216 # Found from Sanjay's paper
# A_R = 2.8663 # Found from Sanjay's paper
# epsilon_0 = 5.346 * 10 ** 36 # Found from Sanjay's paper

# %% [markdown]
# ## (X) Specifying the EoS (change this for different EoS)

# %% [markdown]
# ## (X) Functions to find numerical EoS arrays for Fermi gas given some mass density (in natural units)

# %%
# # Fermi momentum
# def find_k_F(rho):
#     result = (3 * pi ** 2 * rho / m_N) ** (1 / 3)
#     return result

# # Energy density epsilon
# def find_epsilon(rho):
#     k_F = find_k_F(rho).value
#     integrand = lambda k: 1 / (2 * pi ** 2) * k ** 2 * np.sqrt(k ** 2 + m_N.value ** 2)
#     integral, _ = quad(integrand, 0, k_F)
#     result = g * integral * u.MeV ** 4
#     return result

# # Number density
# def find_num_density(rho):
#     k_F = find_k_F(rho).value
#     integrand = lambda k: 1 / (2 * pi ** 2) * k ** 2
#     integral, _ = quad(integrand, 0, k_F)
#     result = g * integral * u.MeV ** 3
#     return result

# # Chemical potential
# def find_chem_potential(rho):
#     k_F = find_k_F(rho)
#     result = np.sqrt(k_F ** 2 + m_N ** 2)
#     return result

# # Pressure
# def find_pressure(rho):
#     k_F = find_k_F(rho)
#     epsilon = find_epsilon(rho)
#     num_density = find_num_density(rho)
#     chem_potential = find_chem_potential(rho)
#     result = - epsilon + chem_potential * num_density
#     return result

# %% [markdown]
# # Good code

# %%
import numpy as np
from scipy.integrate import solve_ivp, odeint, quad
from astropy.constants import G, c
from numpy import pi
import astropy.units as u
import matplotlib.pyplot as plt
import sys
import math
np.set_printoptions(threshold=sys.maxsize)
from scipy import optimize
from sympy import symbols, diff

# %%
# Using natural units
# 197 MeV * fm = 1
# 1 fm = 1 / (197 MeV)
# 3e8 m = 1 s
# 3e8 m / s = 1
# 1 J = 1 kg * (m / s)^2
# 1 J = 1 / 9e16 kg

natural = [(u.MeV, u.fm ** (-1), lambda fm_inverse: 1 / 197 * fm_inverse, lambda MeV: 197 * MeV),
           (u.m, u.s, lambda s: 1 / c.value * s, lambda m: c.value * m),
           (u.kg, u.J, lambda J: c.value ** 2 * J, lambda kg: 1 / c.value ** 2 * kg),
           (u.m / u.s, u.dimensionless_unscaled, lambda dimensionless: 1 / c.value * dimensionless, lambda v: c.value * v),
           (u.fm, u.MeV ** (-1), lambda MeV_inverse: 1 / 197 * MeV_inverse, lambda fm: 197 * fm)
          ]

G = (G.value * (1 * u.m / u.s).to(u.dimensionless_unscaled, equivalencies = natural) ** 2 * (1 * u.m).to(u.fm).to(1 / u.MeV, equivalencies = natural) / (1 * u.kg).to(u.J, equivalencies = natural).to(u.MeV)).value

# %% [markdown]
# ### Initial condition - central mass density

# %%
# Everything in natural units unless otherwise specified
# r_small cannot be 0 b/c it would cause a singularity.

small_r = (0.1 * u.km).to(u.fm).to(1 / u.MeV, equivalencies = natural).value
g = 2
m_N = 939.565 * u.MeV    # Natural units
n_0 = 0.16 / (1 * u.fm).to(1 / u.MeV, equivalencies = natural) ** 3    # Nuclear saturation density

# Setting nuclear parameters
a = 13.0 * u.MeV
alpha = 0.49
b = 3.21 * u.MeV
beta = 2.47

# %% [markdown]
# ### Setting central cumulative mass initial condition

# %%
def M_from_r_and_rho(r, rho):
    result = 4 * pi * rho * r ** 3 / 3
    return result

# %% [markdown]
# ### Horizontal axis scale

# %%
# Everything in natural units unless otherwise specified

R_attempt = (250 * u.km).to(u.fm).to(1 / u.MeV, equivalencies = natural).value

# %% [markdown]
# ## Functions to find numerical EoS arrays for Fermi gas and nuclear strong interaction given some number density (in natural units)

# %%
# Fermi momentum
def find_k_F(num_density):
    result = (3 * pi ** 2 * num_density) ** (1 / 3)
    return result

# Energy density epsilon
def find_epsilon(num_density):
    k_F = find_k_F(num_density).value
    integrand = lambda k: 1 / (2 * pi ** 2) * k ** 2 * np.sqrt(k ** 2 + m_N.value ** 2)
    integral, _ = quad(integrand, 0, k_F)
    result = g * integral * u.MeV ** 4
    return result

# Chemical potential
def find_chem_potential(num_density):
    k_F = find_k_F(num_density)
    result = np.sqrt(k_F ** 2 + m_N ** 2)
    return result

# Pressure
def find_pressure(num_density):
    epsilon = find_epsilon(num_density)
    chem_potential = find_chem_potential(num_density)
    result = - epsilon + chem_potential * num_density
    return result

# %% [markdown]
# ## Generalized TOV and polytropic EoS (this works for NR pure neutron Fermi gas)

# %%
# r = distance from center
# m = cumulative mass enclosed within distance r from center
# p = pressure at distance r from center
# epsilon = energy density at distance r from center

# TOV and EoS coded to be compatible w/ cgs units, but can't explicitly give units in code b/c solve_ivp() throws errors
# Will input A and gamma and epsilon_0 using args paramter for odeint()

# TOV generalized for arbitrary relativity
# A_NR = EoS coefficient for non-relativistic case
# gamma_NR = EoS polytrope exponent for non-relativistic case
# A_R = EoS coefficient for relativistic case
# gamma_R = EoS polytrope exponent for relativistic case
# epsilon_0 = additional EoS coefficient for arbitrary relativity

# EoS returns energy density

def EoS(p, A_NR, A_R, gamma_NR, gamma_R, epsilon_0):
    result = A_NR * p ** (1 / gamma_NR) * epsilon_0 ** (1 - 1 / gamma_NR) + A_R * p ** (1 / gamma_R) * epsilon_0 ** (1 - 1 / gamma_R)
    return result

def TOV(r, p_and_m):
    p = p_and_m[0]
    m = p_and_m[1]
    if num_density_from_pressure(p, r) is None:
        return [0, 0]
    n = num_density_from_pressure(p, r) * u.MeV ** 3
    epsilon = find_epsilon(n).value
    print(f"number density is {n}")
    rel_factors = (1 + p / epsilon) * (1 + 4 * pi * r ** 3 * p / m) * (1 - 2 * G * m / r) ** (-1)
    p_result = - G * epsilon * m / r ** 2 * rel_factors
    m_result = 4 * pi * r ** 2 * epsilon
    return [p_result, m_result]

# %%
# Finding number density as a function of pressure

def pressure_minus_target_p(n, target_p):
    n = n * u.MeV ** 3
    result = find_pressure(n).value - target_p
    return result

def num_density_from_pressure(p, r):
    b = 10 ** 12
    if pressure_minus_target_p(0, p) > 0:
        print(f"Distance from center is {(r / u.MeV).to(u.fm, equivalencies = natural).to(u.km)}, w/ find_pressure {find_pressure(0 * u.MeV ** 3)} and p {p}.")
        return
    result = optimize.brentq(pressure_minus_target_p,
                             0,
                             b,
                             args = (p,))
    return result

# %% [markdown]
# ### TOV solver function

# %%
# Keep this for all EoS

def solve_TOV(n_central, p_central):
    epsilon_central = find_epsilon(n_central * u.MeV ** 3).value
    m_central = M_from_r_and_rho(small_r, epsilon_central)
    def reached_surface(t, y):
        return y[0]

    reached_surface.terminal = True
    reached_surface.direction = -1
    
    solution = solve_ivp(TOV,
                         [small_r, R_attempt],
                         [p_central, m_central],
                         events = reached_surface
                        )

    distance_from_center = (solution.t / u.MeV).to(u.fm, equivalencies = natural).to(u.km)
    print(f"Mass is {(solution.y[1][-1] * u. MeV):.2e}.")
    cumulative_mass = (solution.y[1] * u.MeV).to(u.J).to(u.kg, equivalencies = natural).to(u.solMass)
    pressure = solution.y[0]

    result = distance_from_center, cumulative_mass, pressure
    return result

# %% [markdown]
# ### Solving TOV example

# %%
# Nuclear saturation number density is 0.16 fm^(-3)
n_central = 7 * n_0
print(f"{n_0:.3e}")
p_central = find_pressure(n_central).value
print(f"p_central is {p_central}")
distance_from_center, cumulative_mass, pressure = solve_TOV(n_central.value, p_central)
# Out:
# 1.223e+06 MeV3
# p_central is 635862307.3043976
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000043 MeV3
# number density is 8562817.760000037 MeV3
# number density is 8562817.760000037 MeV3
# number density is 8562817.760000037 MeV3
# number density is 8562817.760000037 MeV3
# number density is 8562817.760000033 MeV3
# number density is 8562817.760000033 MeV3
# number density is 8562817.760000017 MeV3
# number density is 8562817.760000033 MeV3
# number density is 8562817.760000028 MeV3
# number density is 8562817.760000028 MeV3
# number density is 8562817.760000002 MeV3
# number density is 8562817.759999985 MeV3
# number density is 8562817.75999996 MeV3
# number density is 8562817.759999957 MeV3
# number density is 8562817.759999929 MeV3
# number density is 8562817.759999929 MeV3
# number density is 8562817.759999793 MeV3
# number density is 8562817.75999968 MeV3
# number density is 8562817.759999298 MeV3
# number density is 8562817.75999922 MeV3
# number density is 8562817.759999126 MeV3
# number density is 8562817.759999126 MeV3
# number density is 8562817.759997511 MeV3
# number density is 8562817.759996716 MeV3
# number density is 8562817.759992678 MeV3
# number density is 8562817.759991955 MeV3
# number density is 8562817.759991057 MeV3
# number density is 8562817.759991057 MeV3
# number density is 8562817.759974938 MeV3
# number density is 8562817.759966876 MeV3
# number density is 8562817.759926543 MeV3
# number density is 8562817.759919383 MeV3
# number density is 8562817.759910429 MeV3
# number density is 8562817.759910429 MeV3
# number density is 8562817.759749096 MeV3
# number density is 8562817.759668466 MeV3
# number density is 8562817.75926521 MeV3
# number density is 8562817.759193491 MeV3
# number density is 8562817.759103894 MeV3
# number density is 8562817.759103894 MeV3
# number density is 8562817.757490853 MeV3
# number density is 8562817.756684335 MeV3
# number density is 8562817.752651732 MeV3
# number density is 8562817.751934811 MeV3
# number density is 8562817.751038684 MeV3
# number density is 8562817.751038684 MeV3
# number density is 8562817.734908229 MeV3
# number density is 8562817.726842985 MeV3
# number density is 8562817.686516631 MeV3
# number density is 8562817.679347496 MeV3
# number density is 8562817.670386007 MeV3
# number density is 8562817.670386007 MeV3
# number density is 8562817.509079715 MeV3
# number density is 8562817.428422093 MeV3
# number density is 8562817.025128985 MeV3
# number density is 8562816.95342981 MeV3
# number density is 8562816.863804791 MeV3
# number density is 8562816.86380482 MeV3
# number density is 8562815.25054302 MeV3
# number density is 8562814.443465814 MeV3
# number density is 8562810.407576934 MeV3
# number density is 8562809.689817099 MeV3
# number density is 8562808.792519912 MeV3
# number density is 8562808.792532928 MeV3
# number density is 8562792.640054025 MeV3
# number density is 8562784.51942879 MeV3
# number density is 8562743.860503603 MeV3
# number density is 8562736.59764401 MeV3
# number density is 8562727.520892724 MeV3
# number density is 8562727.53385526 MeV3
# number density is 8562564.022982398 MeV3
# number density is 8562478.060595497 MeV3
# number density is 8562037.445547745 MeV3
# number density is 8561948.295002202 MeV3
# number density is 8561848.003898833 MeV3
# number density is 8561860.358861199 MeV3
# number density is 8560026.660934595 MeV3
# number density is 8558837.257239982 MeV3
# number density is 8548470.041298117 MeV3
# number density is 8540832.837019704 MeV3
# number density is 8539420.206160724 MeV3
# number density is 8547738.45070674 MeV3
# number density is 8537457.036487635 MeV3
# number density is 8530596.071616454 MeV3
# number density is 8458820.385271236 MeV3
# number density is 8395992.971022919 MeV3
# number density is 8388329.831117235 MeV3
# number density is 8460789.513738865 MeV3
# number density is 8420051.285682293 MeV3
# number density is 8394283.197110163 MeV3
# number density is 8184530.14867538 MeV3
# number density is 8038672.218157701 MeV3
# number density is 8007640.736978969 MeV3
# number density is 8163892.607241574 MeV3
# number density is 8046571.648837492 MeV3
# number density is 7976656.523766394 MeV3
# number density is 7485626.827864206 MeV3
# number density is 7202696.050269648 MeV3
# number density is 7117600.714975937 MeV3
# number density is 7400617.34453356 MeV3
# number density is 7144233.761991607 MeV3
# number density is 7004240.720573522 MeV3
# number density is 6125793.265618082 MeV3
# number density is 5709216.663370909 MeV3
# number density is 5542996.071783044 MeV3
# number density is 5929483.0982477 MeV3
# number density is 5507794.41724059 MeV3
# number density is 5307923.9513267595 MeV3
# number density is 4144276.230140172 MeV3
# number density is 3697284.320207165 MeV3
# number density is 3475045.1927569285 MeV3
# number density is 3855556.142032393 MeV3
# number density is 3347654.5800337875 MeV3
# number density is 3160173.917985132 MeV3
# number density is 1992538.8287005222 MeV3
# number density is 1452037.135018776 MeV3
# number density is 1206671.8899054234 MeV3
# number density is 1788858.254691033 MeV3
# number density is 1461747.1407701229 MeV3
# number density is 1370553.8850673267 MeV3
# number density is 591301.5746850087 MeV3
# Distance from center is 7.9124235109295435 km, w/ find_pressure 0.0 MeV4 and p -7319656.200329065.
# Distance from center is 8.103245739323835 km, w/ find_pressure 0.0 MeV4 and p -11015643.641216487.
# number density is 604739.6381828767 MeV3
# number density is 1534324.2554120102 MeV3
# number density is 1450424.9092853866 MeV3
# number density is 890684.4463455909 MeV3
# number density is 581864.2316879942 MeV3
# number density is 440831.713456794 MeV3
# number density is 814678.9673878923 MeV3
# number density is 670029.5197055698 MeV3
# number density is 629083.7699106594 MeV3
# number density is 279426.44315409736 MeV3
# Distance from center is 8.848544422592715 km, w/ find_pressure 0.0 MeV4 and p -1888286.4148504138.
# Distance from center is 8.986992383724246 km, w/ find_pressure 0.0 MeV4 and p -2954192.642981544.
# number density is 281993.2565400713 MeV3
# number density is 701611.8929773145 MeV3
# number density is 664104.734039048 MeV3
# number density is 412420.4202356135 MeV3
# number density is 271518.51702499244 MeV3
# number density is 207017.53258863062 MeV3
# number density is 378030.6395418418 MeV3
# number density is 310660.64486405894 MeV3
# number density is 291158.1570744723 MeV3
# number density is 123398.26076526551 MeV3
# Distance from center is 9.547440000841114 km, w/ find_pressure 0.0 MeV4 and p -631720.2471764637.
# Distance from center is 9.649833545883599 km, w/ find_pressure 0.0 MeV4 and p -905288.3196911057.
# number density is 128934.6058244909 MeV3
# number density is 322386.36159472103 MeV3
# number density is 304165.3336321369 MeV3
# number density is 176295.00956181547 MeV3
# number density is 89517.82248414772 MeV3
# number density is 37285.16508397288 MeV3
# number density is 163847.98149474896 MeV3
# number density is 336778.01898586436 MeV3
# number density is 321381.20114115626 MeV3
# number density is 229667.60367348357 MeV3
# number density is 196742.23326888142 MeV3
# number density is 178742.8300865321 MeV3
# number density is 207775.54726346035 MeV3
# number density is 177737.3955769985 MeV3
# number density is 167610.49880625223 MeV3
# number density is 97927.27593547097 MeV3
# number density is 53427.16274085037 MeV3
# number density is 27839.945478893507 MeV3
# number density is 89744.41156867876 MeV3
# number density is 184697.10399563942 MeV3
# number density is 176017.33314695687 MeV3
# number density is 124085.30554739827 MeV3
# number density is 105082.21763659365 MeV3
# number density is 94649.7180463415 MeV3
# number density is 111701.01690849534 MeV3
# number density is 94527.6902731973 MeV3
# number density is 88805.45271688339 MeV3
# number density is 47821.155976552574 MeV3
# number density is 14720.464457934282 MeV3
# Distance from center is 10.205628114052445 km, w/ find_pressure 0.0 MeV4 and p -28890.5444855378.
# number density is 43074.41412013956 MeV3
# number density is 98346.52345962693 MeV3
# number density is 93380.36289621903 MeV3
# number density is 62892.92968597995 MeV3
# number density is 50476.192584264325 MeV3
# number density is 43951.279992004165 MeV3
# number density is 56200.964062569015 MeV3
# number density is 46212.79488756108 MeV3
# number density is 43089.85885451349 MeV3
# number density is 17312.930516124226 MeV3
# Distance from center is 10.424506601191622 km, w/ find_pressure 0.0 MeV4 and p -27472.700373923988.
# Distance from center is 10.46382578865403 km, w/ find_pressure 0.0 MeV4 and p -39178.60046141056.
# number density is 17583.516126700088 MeV3
# number density is 47986.8892486586 MeV3
# number density is 45128.49295102923 MeV3
# number density is 25623.323147035077 MeV3
# number density is 13075.667720684276 MeV3
# number density is 4236.920371625626 MeV3
# number density is 23325.829454357085 MeV3
# number density is 50469.5092493429 MeV3
# number density is 48200.78466590234 MeV3
# number density is 35081.801911957 MeV3
# number density is 30929.860603499506 MeV3
# number density is 28295.986998212757 MeV3
# number density is 31479.874087583077 MeV3
# number density is 26909.951869939414 MeV3
# number density is 25296.693016662106 MeV3
# number density is 14401.392802954866 MeV3
# number density is 7633.063696890245 MeV3
# number density is 3031.9697168662697 MeV3
# number density is 12983.726992198412 MeV3
# number density is 28221.369751063674 MeV3
# number density is 26927.297732475483 MeV3
# number density is 19426.917687976835 MeV3
# number density is 17030.876027774008 MeV3
# number density is 15510.651014465082 MeV3
# number density is 17368.776033934868 MeV3
# number density is 14744.086182646757 MeV3
# number density is 13826.26048189432 MeV3
# number density is 7475.578518680621 MeV3
# number density is 2928.7379056653285 MeV3
# Distance from center is 10.620625981000604 km, w/ find_pressure 0.0 MeV4 and p -813.1204200060602.
# number density is 6723.351621413446 MeV3
# number density is 15574.681443452779 MeV3
# number density is 14857.788350372584 MeV3
# number density is 10711.66608675531 MeV3
# number density is 9400.76907311294 MeV3
# number density is 8556.74531106344 MeV3
# number density is 9560.04085047055 MeV3
# number density is 8099.374638559277 MeV3
# number density is 7587.91581436114 MeV3
# number density is 4031.785195995579 MeV3
# number density is 1368.5778911515692 MeV3
# Distance from center is 10.679620578747825 km, w/ find_pressure 0.0 MeV4 and p -453.7106230838817.
# number density is 3551.373901221645 MeV3
# number density is 8487.555895834623 MeV3
# number density is 8066.92428439877 MeV3
# number density is 5574.445662332281 MeV3
# number density is 4696.812225708763 MeV3
# number density is 4172.189321141831 MeV3
# number density is 4933.3362956606325 MeV3
# number density is 4068.9777459400566 MeV3
# number density is 3785.388977442039 MeV3
# number density is 1544.3622040496427 MeV3
# Distance from center is 10.722385458423366 km, w/ find_pressure 0.0 MeV4 and p -405.51053625654276.
# Distance from center is 10.731077551210495 km, w/ find_pressure 0.0 MeV4 and p -640.2456168070407.
# number density is 1438.7058640531486 MeV3
# number density is 4277.2657089791155 MeV3
# number density is 4032.9465961008664 MeV3
# number density is 2480.308750858627 MeV3
# number density is 1736.9524018122556 MeV3
# number density is 1325.2166192824861 MeV3
# number density is 2176.993864835553 MeV3
# number density is 1719.0827505930872 MeV3
# number density is 1585.6545878596755 MeV3
# Distance from center is 10.75672609284555 km, w/ find_pressure 0.0 MeV4 and p -3.023145257655756.
# Distance from center is 10.761568238696029 km, w/ find_pressure 0.0 MeV4 and p -402.25740914583344.
# Distance from center is 10.767620921009126 km, w/ find_pressure 0.0 MeV4 and p -267.65845351973894.
# number density is 1101.6560062933427 MeV3
# number density is 1950.7548084812397 MeV3
# number density is 1859.6451977927693 MeV3
# number density is 1333.2321656068234 MeV3
# number density is 1167.746823722955 MeV3
# number density is 1059.5787327048774 MeV3
# number density is 1185.2761628416602 MeV3
# number density is 998.1217948812565 MeV3
# number density is 932.8954521020656 MeV3
# number density is 470.1191927628972 MeV3
# number density is 21.574803742680764 MeV3
# Distance from center is 10.769108499222638 km, w/ find_pressure 0.0 MeV4 and p -32.77328206035094.
# number density is 355.45793725744755 MeV3
# number density is 1057.3904768518464 MeV3
# number density is 1006.3328495793694 MeV3
# number density is 708.2101697959255 MeV3
# number density is 609.9282150391728 MeV3
# number density is 547.9092919304394 MeV3
# number density is 627.1324908391776 MeV3
# number density is 521.9049322343191 MeV3
# number density is 486.27305555868287 MeV3
# number density is 219.17547283011066 MeV3
# Distance from center is 10.77789865341057 km, w/ find_pressure 0.0 MeV4 and p -7.133817139252798.
# Distance from center is 10.780061654216668 km, w/ find_pressure 0.0 MeV4 and p -16.90401020126103.
# number density is 177.6722030211551 MeV3
# number density is 554.8506665576398 MeV3
# number density is 526.4953909565606 MeV3
# number density is 357.3670576389872 MeV3
# number density is 296.02646128435237 MeV3
# number density is 259.5983223904167 MeV3
# number density is 314.5518358707736 MeV3
# number density is 255.78875976749447 MeV3
# number density is 237.05787286337022 MeV3
# number density is 76.5852564406892 MeV3
# Distance from center is 10.786337806685816 km, w/ find_pressure 0.0 MeV4 and p -7.270976110913175.
# Distance from center is 10.787852110198994 km, w/ find_pressure 0.0 MeV4 and p -8.26795458537891.
# number density is 98.16417069238273 MeV3
# number density is 56.991119063156354 MeV3
# number density is 55.578769761008054 MeV3
# Distance from center is 10.798138138086593 km, w/ find_pressure 0.0 MeV4 and p -6.17970301264187.
# Distance from center is 10.799281030074107 km, w/ find_pressure 0.0 MeV4 and p -18.329578168969203.
# Distance from center is 10.800709645058493 km, w/ find_pressure 0.0 MeV4 and p -16.574526033015587.
# Distance from center is 10.800709645058493 km, w/ find_pressure 0.0 MeV4 and p -0.12280469618760126.
# number density is 68.7562794531593 MeV3
# number density is 63.16724148608667 MeV3
# Distance from center is 10.795577199006472 km, w/ find_pressure 0.0 MeV4 and p -1.9392476839310948.
# Distance from center is 10.796435542207302 km, w/ find_pressure 0.0 MeV4 and p -6.705758590127315.
# Distance from center is 10.79750847120834 km, w/ find_pressure 0.0 MeV4 and p -5.66935768529779.
# number density is 31.387117678206582 MeV3
# number density is 83.62976792902957 MeV3
# number density is 78.40151142487908 MeV3
# number density is 43.12110588181873 MeV3
# number density is 20.424916770118955 MeV3
# Distance from center is 10.792908686735018 km, w/ find_pressure 0.0 MeV4 and p -0.03253112540752934.
# number density is 39.199332536020776 MeV3
# number density is 88.99748321007115 MeV3
# number density is 85.20137034279679 MeV3
# number density is 63.85057018428488 MeV3
# number density is 57.92388207702023 MeV3
# number density is 53.58924553447967 MeV3
# number density is 57.32156348106357 MeV3
# number density is 49.54943768732824 MeV3
# number density is 46.65443948237466 MeV3
# number density is 28.131754866743993 MeV3
# number density is 18.945519314994748 MeV3
# number density is 13.695674180040811 MeV3
# number density is 24.62015767542551 MeV3
# number density is 50.65756649476476 MeV3
# number density is 48.04649911100313 MeV3
# number density is 32.43189501993383 MeV3
# number density is 26.70187605314278 MeV3
# number density is 23.31404494367229 MeV3
# number density is 28.510899796592188 MeV3
# number density is 23.090226567717654 MeV3
# number density is 21.378934298127245 MeV3
# number density is 6.308705123264089 MeV3
# Distance from center is 10.796407796043066 km, w/ find_pressure 0.0 MeV4 and p -0.1508065890609106.
# Distance from center is 10.796719773297667 km, w/ find_pressure 0.0 MeV4 and p -0.1598370380545261.
# number density is 9.22776435659599 MeV3
# number density is 24.308517167214333 MeV3
# number density is 22.793426432071175 MeV3
# number density is 12.602757466678407 MeV3
# number density is 6.157852103411882 MeV3
# Distance from center is 10.796123237403553 km, w/ find_pressure 0.0 MeV4 and p -0.0009675585290416233.
# number density is 11.498299058138308 MeV3
# number density is 25.890303500660526 MeV3
# number density is 24.801129796588857 MeV3
# number density is 18.695966502166563 MeV3
# number density is 17.027955693267018 MeV3
# number density is 15.789063926725829 MeV3
# number density is 16.810237594612673 MeV3
# number density is 14.581477982472975 MeV3
# number density is 13.744354520896646 MeV3
# number density is 8.45059874602647 MeV3
# number density is 5.960067099004035 MeV3
# number density is 4.560026387938854 MeV3
# number density is 7.388246071372139 MeV3
# number density is 5.808276620625921 MeV3
# number density is 5.3502042054717895 MeV3
# Distance from center is 10.797743518021939 km, w/ find_pressure 0.0 MeV4 and p -0.0011425356292336028.
# Distance from center is 10.797856680542814 km, w/ find_pressure 0.0 MeV4 and p -0.032473359738225044.
# Distance from center is 10.797998133693914 km, w/ find_pressure 0.0 MeV4 and p -0.022004576694280284.
# number density is 3.6741149929898764 MeV3
# number density is 6.606981347299764 MeV3
# number density is 6.292718821372777 MeV3
# number density is 4.469819591561288 MeV3
# number density is 3.886685452694397 MeV3
# number density is 3.509303772929738 MeV3
# number density is 3.9623121430100876 MeV3
# number density is 3.314296326949788 MeV3
# number density is 3.091426767035019 MeV3
# number density is 1.4643100904217226 MeV3
# Distance from center is 10.797962156967946 km, w/ find_pressure 0.0 MeV4 and p -0.0008510652002267222.
# Distance from center is 10.798034927652296 km, w/ find_pressure 0.0 MeV4 and p -0.0031956282768494555.
# number density is 1.1209193800324893 MeV3
# number density is 3.5268005724998375 MeV3
# number density is 3.3533903646365086 MeV3
# number density is 2.3358096545007325 MeV3
# number density is 1.9927736675640084 MeV3
# number density is 1.779091175426248 MeV3
# number density is 2.0630160152279235 MeV3
# number density is 1.7044921254985301 MeV3
# number density is 1.5850324034960412 MeV3
# number density is 0.6566608874412919 MeV3
# Distance from center is 10.798227661705468 km, w/ find_pressure 0.0 MeV4 and p -0.0008587032294562098.
# Distance from center is 10.798277524659133 km, w/ find_pressure 0.0 MeV4 and p -0.001445878976919104.
# number density is 0.5872196292266587 MeV3
# number density is 1.7916498019242895 MeV3
# number density is 1.6894257171226252 MeV3
# number density is 1.0455600909491547 MeV3
# number density is 0.7479918592603473 MeV3
# number density is 0.5811645632365485 MeV3
# number density is 0.9139583464762594 MeV3
# number density is 0.7121713707818333 MeV3
# number density is 0.6552113367115999 MeV3
# Distance from center is 10.798434151742452 km, w/ find_pressure 0.0 MeV4 and p -8.861367972482718e-05.
# Distance from center is 10.798463090829827 km, w/ find_pressure 0.0 MeV4 and p -0.001106492134703518.
# Distance from center is 10.798499264689045 km, w/ find_pressure 0.0 MeV4 and p -0.0007778751399890949.
# number density is 0.4413342992811345 MeV3
# number density is 0.8049323617989409 MeV3
# number density is 0.7625279485296421 MeV3
# number density is 0.5065398597695933 MeV3
# number density is 0.4085685238167366 MeV3
# number density is 0.35177959520405194 MeV3
# number density is 0.44439993225218666 MeV3
# number density is 0.3561464520854824 MeV3
# number density is 0.3290810618520479 MeV3
# number density is 0.06950809526372145 MeV3
# Distance from center is 10.798518626186294 km, w/ find_pressure 0.0 MeV4 and p -0.00019509874457249328.
# Distance from center is 10.798538915964544 km, w/ find_pressure 0.0 MeV4 and p -0.00017542307920087336.
# number density is 0.16358776902962752 MeV3
# number density is 0.3764764212022371 MeV3
# number density is 0.35236111736934755 MeV3
# number density is 0.18595172003067584 MeV3
# number density is 0.0632402643117076 MeV3
# Distance from center is 10.798499248212464 km, w/ find_pressure 0.0 MeV4 and p -2.81744959934315e-05.
# number density is 0.16209367456346363 MeV3
# number density is 0.11498968217867825 MeV3
# number density is 0.10550569221671513 MeV3
# Distance from center is 10.798604566157525 km, w/ find_pressure 0.0 MeV4 and p -3.9487939981980595e-05.
# Distance from center is 10.798616268151422 km, w/ find_pressure 0.0 MeV4 and p -0.00014141169085645053.
# Distance from center is 10.798630895643791 km, w/ find_pressure 0.0 MeV4 and p -0.00011826675158504074.
# number density is 0.05486356216855724 MeV3
# number density is 0.12309844173900553 MeV3
# number density is 0.11295960891101801 MeV3
# Distance from center is 10.798588162807281 km, w/ find_pressure 0.0 MeV4 and p -1.384752293573633e-05.
# Distance from center is 10.798598042206704 km, w/ find_pressure 0.0 MeV4 and p -8.091566938694971e-05.
# Distance from center is 10.798610391455984 km, w/ find_pressure 0.0 MeV4 and p -6.133723732165258e-05.
# number density is 0.07165632284367268 MeV3
# number density is 0.13020769712593527 MeV3
# number density is 0.12036397273618166 MeV3
# number density is 0.027917893543661677 MeV3
# Distance from center is 10.798581388751147 km, w/ find_pressure 0.0 MeV4 and p -3.4218477477635884e-05.
# Distance from center is 10.798591656318484 km, w/ find_pressure 0.0 MeV4 and p -3.1893106132365904e-05.
# number density is 0.05774046159443163 MeV3
# number density is 0.032887032016674166 MeV3
# number density is 0.032401005608826104 MeV3
# Distance from center is 10.798665582803297 km, w/ find_pressure 0.0 MeV4 and p -2.7701505817742398e-05.
# Distance from center is 10.798673796857164 km, w/ find_pressure 0.0 MeV4 and p -8.190425312567229e-05.
# Distance from center is 10.7986840644245 km, w/ find_pressure 0.0 MeV4 and p -7.424724707471813e-05.
# Distance from center is 10.7986840644245 km, w/ find_pressure 0.0 MeV4 and p -7.825303709172761e-07.
# Mass is 7.64e+59 MeV.

# %%
fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 8))

ax1.set_title("Cumulative mass vs distance from center");
ax1.set_xlabel("Distance from center (km)");
ax1.set_ylabel(r"Cumulative mass ($\mathrm{M_{\odot}}$)");
# ax1.set_xlim(0, 20);
# ax1.set_ylim(0, 0.6);
ax1.plot(distance_from_center, cumulative_mass);
ax2.set_title("Pressure vs distance from center");
ax2.set_xlabel("Distance from center (km)");
ax2.set_ylabel(r"Pressure $\left(\mathrm{MeV/\,fm^3}\right)$");
# ax2.set_xlim(0, 20);
ax2.plot(distance_from_center, pressure);

# %%
print(f"Mass is {np.max(cumulative_mass):.2f}.")
# Out:
# Mass is 0.68 solMass.

# %% [markdown]
# ## Making mass-radius plot

# %%
mass = []
radius = []
pressure_list = []

# Nuclear saturation number density is 0.16 fm^(-3)
n_central = np.logspace(-1, 2, num = 50) * n_0

for num_density in n_central:
    p_central = find_pressure(num_density).value
    distance_from_center, cumulative_mass, pressure = solve_TOV(num_density.value, p_central)
    print("Solved TOV")

    # Removing NaN and inf values from cumulative mass
    
    cumulative_mass = cumulative_mass[~np.isnan(cumulative_mass)]
    cumulative_mass = cumulative_mass[~np.isinf(cumulative_mass)]
        
    mass.append(cumulative_mass[-1].value)
    radius.append(distance_from_center[-1].value)
    pressure_list.append(pressure[0])
# Out:
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.968000003 MeV3
# number density is 122325.9679999998 MeV3
# number density is 122325.9679999998 MeV3
# number density is 122325.9679999998 MeV3
# number density is 122325.9679999998 MeV3
# number density is 122325.96800000139 MeV3
# number density is 122325.96800000261 MeV3
# number density is 122325.96799999669 MeV3
# number density is 122325.96799999784 MeV3
# number density is 122325.9679999996 MeV3
# number density is 122325.9679999996 MeV3
# number density is 122325.96800000075 MeV3
# number density is 122325.96800000108 MeV3
# number density is 122325.96800000004 MeV3
# number density is 122325.96800000076 MeV3
# number density is 122325.96800000254 MeV3
# number density is 122325.96800000254 MeV3
# number density is 122325.9679999999 MeV3
# number density is 122325.96799999627 MeV3
# number density is 122325.96799998655 MeV3
# number density is 122325.9679999846 MeV3
# number density is 122325.96799998396 MeV3
# number density is 122325.96799998396 MeV3
# number density is 122325.96799995507 MeV3
# number density is 122325.96799993988 MeV3
# number density is 122325.96799986734 MeV3
# number density is 122325.96799985517 MeV3
# number density is 122325.9679998355 MeV3
# number density is 122325.9679998355 MeV3
# number density is 122325.96799954135 MeV3
# number density is 122325.96799939434 MeV3
# number density is 122325.96799865224 MeV3
# number density is 122325.9679985221 MeV3
# number density is 122325.96799835585 MeV3
# number density is 122325.96799835585 MeV3
# number density is 122325.9679953916 MeV3
# number density is 122325.96799391026 MeV3
# number density is 122325.96798649727 MeV3
# number density is 122325.96798518373 MeV3
# number density is 122325.96798353561 MeV3
# number density is 122325.96798353561 MeV3
# number density is 122325.96795389213 MeV3
# number density is 122325.96793907094 MeV3
# number density is 122325.96786496625 MeV3
# number density is 122325.96785179098 MeV3
# number density is 122325.96783532751 MeV3
# number density is 122325.96783532751 MeV3
# number density is 122325.96753890286 MeV3
# number density is 122325.96739068796 MeV3
# number density is 122325.96664958712 MeV3
# number density is 122325.96651782759 MeV3
# number density is 122325.96635312948 MeV3
# number density is 122325.96635313061 MeV3
# number density is 122325.96338856334 MeV3
# number density is 122325.96190545721 MeV3
# number density is 122325.95448900975 MeV3
# number density is 122325.95317003097 MeV3
# number density is 122325.95152113671 MeV3
# number density is 122325.95152116899 MeV3
# number density is 122325.92183898123 MeV3
# number density is 122325.90691637617 MeV3
# number density is 122325.83219866807 MeV3
# number density is 122325.81884886589 MeV3
# number density is 122325.80216948815 MeV3
# number density is 122325.80219789043 MeV3
# number density is 122325.50172635172 MeV3
# number density is 122325.34384570761 MeV3
# number density is 122324.53252923017 MeV3
# number density is 122324.36550910023 MeV3
# number density is 122324.18154126122 MeV3
# number density is 122324.20860577794 MeV3
# number density is 122320.83892263491 MeV3
# number density is 122318.71358216362 MeV3
# number density is 122298.57723371522 MeV3
# number density is 122282.4101889994 MeV3
# number density is 122280.041152872 MeV3
# number density is 122298.23869472597 MeV3
# number density is 122270.33698898996 MeV3
# number density is 122252.44175688564 MeV3
# number density is 121944.62675202108 MeV3
# number density is 121594.37666768214 MeV3
# number density is 121582.26122758831 MeV3
# number density is 122014.87874958431 MeV3
# number density is 121852.36192345059 MeV3
# number density is 121748.92968947825 MeV3
# number density is 120629.50644366312 MeV3
# number density is 119620.21005710846 MeV3
# number density is 119512.00109483622 MeV3
# number density is 120688.72183095712 MeV3
# number density is 120074.9098387925 MeV3
# number density is 119696.90559623715 MeV3
# number density is 116466.28638252779 MeV3
# number density is 114075.78211402125 MeV3
# number density is 113640.39309596887 MeV3
# number density is 116265.03017686459 MeV3
# number density is 114544.06967373267 MeV3
# number density is 113535.79619061209 MeV3
# number density is 106212.18279654742 MeV3
# number density is 101737.10700248019 MeV3
# number density is 100537.30663831964 MeV3
# number density is 105134.97218870724 MeV3
# number density is 101415.2097256429 MeV3
# number density is 99401.72347101997 MeV3
# number density is 86503.1424515589 MeV3
# number density is 80124.8579816095 MeV3
# number density is 77730.94463016132 MeV3
# number density is 83773.13789731266 MeV3
# number density is 77619.06534816085 MeV3
# number density is 74706.9843557128 MeV3
# number density is 57636.29885823603 MeV3
# number density is 51143.42254040507 MeV3
# number density is 47819.41190150003 MeV3
# number density is 53271.76294416499 MeV3
# number density is 45671.4922113851 MeV3
# number density is 42895.56935496289 MeV3
# number density is 25333.354978510302 MeV3
# number density is 16921.420970949323 MeV3
# number density is 12462.756570526359 MeV3
# number density is 22201.817441723528 MeV3
# number density is 46946.13125482587 MeV3
# number density is 44478.40353002606 MeV3
# number density is 29976.310993479216 MeV3
# number density is 25001.1093368334 MeV3
# number density is 22184.610945171724 MeV3
# number density is 26398.526197672807 MeV3
# number density is 21590.306312224355 MeV3
# number density is 20168.40116940726 MeV3
# number density is 8586.220291609732 MeV3
# Distance from center is 20.67399018366511 km, w/ find_pressure 0.0 MeV4 and p -5987.429781418359.
# Distance from center is 21.13898186425404 km, w/ find_pressure 0.0 MeV4 and p -9833.131209566804.
# number density is 8112.886340561711 MeV3
# number density is 22858.54311228262 MeV3
# number density is 21612.359118252836 MeV3
# number density is 13735.922851576132 MeV3
# number density is 10197.21151223884 MeV3
# number density is 8429.128767976159 MeV3
# number density is 12239.468182172273 MeV3
# number density is 9803.893115974397 MeV3
# number density is 9141.745059573104 MeV3
# number density is 2530.7211625023556 MeV3
# Distance from center is 22.876607788027098 km, w/ find_pressure 0.0 MeV4 and p -4461.090653275816.
# Distance from center is 23.22499314385494 km, w/ find_pressure 0.0 MeV4 and p -4398.420855757358.
# number density is 4493.803295793361 MeV3
# number density is 10501.599156798045 MeV3
# number density is 9910.738381439955 MeV3
# number density is 5952.800495617519 MeV3
# number density is 3705.9596229001468 MeV3
# number density is 2544.42340021827 MeV3
# number density is 5384.804252209102 MeV3
# number density is 10758.66439003469 MeV3
# number density is 10218.936801481059 MeV3
# number density is 6904.54378222911 MeV3
# number density is 5571.49222505464 MeV3
# number density is 4882.787802587184 MeV3
# number density is 6187.4103584666445 MeV3
# number density is 5121.81390981716 MeV3
# number density is 4793.154288143233 MeV3
# number density is 2158.27343286948 MeV3
# Distance from center is 23.794447536207713 km, w/ find_pressure 0.0 MeV4 and p -442.80575724158825.
# Distance from center is 24.012384159431445 km, w/ find_pressure 0.0 MeV4 and p -823.3075189906667.
# number density is 1976.181954863423 MeV3
# number density is 5407.841746505755 MeV3
# number density is 5125.655525689456 MeV3
# number density is 3352.999895259057 MeV3
# number density is 2567.1721702333766 MeV3
# number density is 2170.70484150559 MeV3
# number density is 2999.41782989416 MeV3
# number density is 2433.5577139791562 MeV3
# number density is 2266.104675377122 MeV3
# number density is 746.0251853921051 MeV3
# Distance from center is 24.807279512417107 km, w/ find_pressure 0.0 MeV4 and p -336.5992345715151.
# Distance from center is 24.96941627488765 km, w/ find_pressure 0.0 MeV4 and p -372.3189295266948.
# number density is 1013.1491282116173 MeV3
# number density is 2498.157528580315 MeV3
# number density is 2337.374989404564 MeV3
# number density is 1098.51786585395 MeV3
# Distance from center is 24.668390352137568 km, w/ find_pressure 0.0 MeV4 and p -87.76369756393478.
# Distance from center is 24.813165969573166 km, w/ find_pressure 0.0 MeV4 and p -217.8231239232548.
# number density is 935.193722247538 MeV3
# number density is 2649.1708356060803 MeV3
# number density is 2517.0757221915187 MeV3
# number density is 1716.2764919041788 MeV3
# number density is 1407.3082744505791 MeV3
# number density is 1238.6060792671797 MeV3
# number density is 1530.2757422913487 MeV3
# number density is 1263.573884267708 MeV3
# number density is 1178.6947847717393 MeV3
# number density is 498.2024173728165 MeV3
# Distance from center is 25.2615039584523 km, w/ find_pressure 0.0 MeV4 and p -54.70714488083502.
# Distance from center is 25.364522696440503 km, w/ find_pressure 0.0 MeV4 and p -88.76276160213223.
# number density is 468.2449636874364 MeV3
# number density is 1328.452951085475 MeV3
# number density is 1254.7918322800642 MeV3
# number density is 784.030595996321 MeV3
# number density is 556.679622367647 MeV3
# number density is 437.070282009293 MeV3
# number density is 695.3643074325151 MeV3
# number density is 554.3518472582293 MeV3
# number density is 513.222217490009 MeV3
# number density is 87.1298275546513 MeV3
# Distance from center is 25.742217524362257 km, w/ find_pressure 0.0 MeV4 and p -47.29964311292815.
# Distance from center is 25.81625745915058 km, w/ find_pressure 0.0 MeV4 and p -39.870281098102794.
# number density is 280.33541264328335 MeV3
# number density is 613.7239635259004 MeV3
# number density is 582.3540519623554 MeV3
# number density is 392.9276524588015 MeV3
# number density is 320.6517560709172 MeV3
# number density is 279.76946880168026 MeV3
# number density is 347.561288690526 MeV3
# number density is 283.1733902792735 MeV3
# number density is 262.91232014345314 MeV3
# number density is 89.35089980819095 MeV3
# Distance from center is 25.901759914654757 km, w/ find_pressure 0.0 MeV4 and p -8.133110774041832.
# Distance from center is 25.94598708339588 km, w/ find_pressure 0.0 MeV4 and p -9.56584658023452.
# number density is 109.13241702261304 MeV3
# number density is 53.396428684450186 MeV3
# number density is 58.96414563801221 MeV3
# Distance from center is 26.311200751700216 km, w/ find_pressure 0.0 MeV4 and p -13.740468332949305.
# Distance from center is 26.351780048178473 km, w/ find_pressure 0.0 MeV4 and p -40.34603199538597.
# Distance from center is 26.402504168776296 km, w/ find_pressure 0.0 MeV4 and p -37.00539844865001.
# Distance from center is 26.402504168776296 km, w/ find_pressure 0.0 MeV4 and p -0.7779823410866626.
# number density is 70.33455184483867 MeV3
# number density is 65.85472843402385 MeV3
# Distance from center is 26.21831565968563 km, w/ find_pressure 0.0 MeV4 and p -4.318707967461041.
# Distance from center is 26.24857439038449 km, w/ find_pressure 0.0 MeV4 and p -13.363433514299025.
# Distance from center is 26.286397803758067 km, w/ find_pressure 0.0 MeV4 and p -11.813499328268154.
# number density is 21.234356100201378 MeV3
# number density is 88.95912838274066 MeV3
# number density is 82.53523389385744 MeV3
# number density is 28.08502167449012 MeV3
# Distance from center is 26.11425255261146 km, w/ find_pressure 0.0 MeV4 and p -1.1541317132301803.
# Distance from center is 26.13528573626341 km, w/ find_pressure 0.0 MeV4 and p -1.371439942123283.
# number density is 33.716191551108416 MeV3
# number density is 18.79442413066117 MeV3
# number density is 18.7893747714923 MeV3
# Distance from center is 26.286724658557432 km, w/ find_pressure 0.0 MeV4 and p -1.2364944858994653.
# Distance from center is 26.303551205478993 km, w/ find_pressure 0.0 MeV4 and p -3.6509501321665176.
# Distance from center is 26.324584389130937 km, w/ find_pressure 0.0 MeV4 and p -3.318676518527676.
# Distance from center is 26.324584389130937 km, w/ find_pressure 0.0 MeV4 and p -0.04256910409010961.
# number density is 23.10684984390435 MeV3
# number density is 21.304745314730564 MeV3
# Distance from center is 26.248972453812105 km, w/ find_pressure 0.0 MeV4 and p -0.3954349609608643.
# Distance from center is 26.261604311317512 km, w/ find_pressure 0.0 MeV4 and p -1.308964393776515.
# Distance from center is 26.277394133199277 km, w/ find_pressure 0.0 MeV4 and p -1.1241923709927901.
# number density is 9.730014934969246 MeV3
# number density is 28.42719630167488 MeV3
# number density is 26.57784138717592 MeV3
# number density is 13.52847663847539 MeV3
# number density is 1.9968816882633758 MeV3
# Distance from center is 26.21056308912328 km, w/ find_pressure 0.0 MeV4 and p -0.073061798117672.
# number density is 10.862487055003887 MeV3
# number density is 29.3352600527329 MeV3
# number density is 27.682396126996103 MeV3
# number density is 17.320660412747927 MeV3
# number density is 12.638925948736919 MeV3
# number density is 10.035075668517763 MeV3
# number density is 15.160860487475903 MeV3
# number density is 11.916524057863288 MeV3
# number density is 10.979273168959455 MeV3
# Distance from center is 26.245686337323853 km, w/ find_pressure 0.0 MeV4 and p -0.0038640818865635085.
# Distance from center is 26.25095700400585 km, w/ find_pressure 0.0 MeV4 and p -0.10800261166303943.
# Distance from center is 26.25754533735836 km, w/ find_pressure 0.0 MeV4 and p -0.0733343494446475.
# number density is 7.5428626849450175 MeV3
# number density is 13.559676325401437 MeV3
# number density is 12.916162723160515 MeV3
# number density is 9.183358947119327 MeV3
# number density is 7.989127487820986 MeV3
# number density is 7.217372196358941 MeV3
# number density is 8.145196588112878 MeV3
# number density is 6.819586423606855 MeV3
# number density is 6.363188640163159 MeV3
# number density is 3.0432867248077025 MeV3
# Distance from center is 26.25576493329662 km, w/ find_pressure 0.0 MeV4 and p -0.002413318554434052.
# Distance from center is 26.25914814483255 km, w/ find_pressure 0.0 MeV4 and p -0.010328434976532477.
# number density is 2.314416919404184 MeV3
# number density is 7.263911310329266 MeV3
# number density is 6.91180647905948 MeV3
# number density is 4.855068221600328 MeV3
# number density is 4.175926257086317 MeV3
# number density is 3.7470853675107385 MeV3
# number density is 4.29565579436015 MeV3
# number density is 3.5689356503206673 MeV3
# number density is 3.323496949978941 MeV3
# number density is 1.470071426317631 MeV3
# Distance from center is 26.26769556921469 km, w/ find_pressure 0.0 MeV4 and p -0.0020223386131214584.
# Distance from center is 26.26998947087384 km, w/ find_pressure 0.0 MeV4 and p -0.0043482133743972355.
# number density is 1.2135906080811747 MeV3
# number density is 3.786139944068939 MeV3
# number density is 3.587747496511748 MeV3
# number density is 2.3923973417178264 MeV3
# number density is 1.9388935722542031 MeV3
# number density is 1.675242445958784 MeV3
# number density is 2.1002942028742884 MeV3
# number density is 1.6877876609584954 MeV3
# number density is 1.5603971065530224 MeV3
# number density is 0.3673473122362585 MeV3
# Distance from center is 26.27719116805622 km, w/ find_pressure 0.0 MeV4 and p -0.002422459135900683.
# Distance from center is 26.27882921582767 km, w/ find_pressure 0.0 MeV4 and p -0.0022716483964976743.
# number density is 0.7446563911529492 MeV3
# number density is 1.8267782347269437 MeV3
# number density is 1.7234248833383563 MeV3
# number density is 1.0754862856830356 MeV3
# number density is 0.7823025908596964 MeV3
# number density is 0.6183975485779089 MeV3
# number density is 0.9402893592230244 MeV3
# number density is 0.7324107243694359 MeV3
# number density is 0.6738279274229703 MeV3
# Distance from center is 26.281805309085247 km, w/ find_pressure 0.0 MeV4 and p -9.527571662632526e-05.
# Distance from center is 26.282661215213295 km, w/ find_pressure 0.0 MeV4 and p -0.001165407287912913.
# Distance from center is 26.28373109787336 km, w/ find_pressure 0.0 MeV4 and p -0.0008205941119601256.
# number density is 0.4535535430074694 MeV3
# number density is 0.8283649221626249 MeV3
# number density is 0.7848135920810141 MeV3
# number density is 0.5220976468841408 MeV3
# number density is 0.4218894110192031 MeV3
# number density is 0.363736622391298 MeV3
# number density is 0.4581587854604084 MeV3
# number density is 0.3675496842191097 MeV3
# number density is 0.3396880656787939 MeV3
# number density is 0.07492265581856575 MeV3
# Distance from center is 26.284270132270553 km, w/ find_pressure 0.0 MeV4 and p -0.0002000186969615365.
# Distance from center is 26.28486824864336 km, w/ find_pressure 0.0 MeV4 and p -0.00018272456215578882.
# number density is 0.16621110329355904 MeV3
# number density is 0.3877083611810385 MeV3
# number density is 0.36276749125809354 MeV3
# number density is 0.1898572548352619 MeV3
# number density is 0.0581228974703517 MeV3
# Distance from center is 26.28373928436449 km, w/ find_pressure 0.0 MeV4 and p -3.511951403219714e-05.
# number density is 0.1634236437508745 MeV3
# number density is 0.11152349754741334 MeV3
# number density is 0.10279197201687913 MeV3
# Distance from center is 26.287059694570484 km, w/ find_pressure 0.0 MeV4 and p -5.668728387900283e-05.
# Distance from center is 26.28742862903782 km, w/ find_pressure 0.0 MeV4 and p -0.00018592716082578575.
# Distance from center is 26.287889797121984 km, w/ find_pressure 0.0 MeV4 and p -0.0001599707744092017.
# number density is 0.045770578355235736 MeV3
# number density is 0.11980236775514366 MeV3
# number density is 0.10979234519182583 MeV3
# Distance from center is 26.28658705099705 km, w/ find_pressure 0.0 MeV4 and p -2.7050910841463024e-05.
# Distance from center is 26.286903469511778 km, w/ find_pressure 0.0 MeV4 and p -0.00011179425687568332.
# Distance from center is 26.287298992655188 km, w/ find_pressure 0.0 MeV4 and p -9.01766764504932e-05.
# number density is 0.06338801730573544 MeV3
# number density is 0.12771637550214301 MeV3
# number density is 0.11754728520521472 MeV3
# Distance from center is 26.286114386964915 km, w/ find_pressure 0.0 MeV4 and p -4.02020694546736e-06.
# Distance from center is 26.286378287253854 km, w/ find_pressure 0.0 MeV4 and p -6.072455909126589e-05.
# Distance from center is 26.286708162615025 km, w/ find_pressure 0.0 MeV4 and p -4.2208934103031564e-05.
# number density is 0.07969232412805942 MeV3
# number density is 0.13427603973648 MeV3
# number density is 0.12470547723798428 MeV3
# number density is 0.04796526570733553 MeV3
# Distance from center is 26.28592616563584 km, w/ find_pressure 0.0 MeV4 and p -1.65261956600169e-05.
# Distance from center is 26.28619952579476 km, w/ find_pressure 0.0 MeV4 and p -2.3487923856288604e-05.
# number density is 0.04748719825030632 MeV3
# number density is 0.025882302604337958 MeV3
# number density is 0.026203136259739655 MeV3
# Distance from center is 26.288167718938976 km, w/ find_pressure 0.0 MeV4 and p -2.383767021978685e-05.
# Distance from center is 26.28838640706611 km, w/ find_pressure 0.0 MeV4 and p -7.016469332855462e-05.
# Distance from center is 26.288659767225028 km, w/ find_pressure 0.0 MeV4 and p -6.39020252062835e-05.
# Distance from center is 26.288659767225028 km, w/ find_pressure 0.0 MeV4 and p -9.975508156684051e-07.
# Mass is 1.88e+59 MeV.
# Solved TOV
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.55677335462 MeV3
# number density is 140845.5567733567 MeV3
# number density is 140845.5567733567 MeV3
# number density is 140845.5567733567 MeV3
# number density is 140845.5567733567 MeV3
# number density is 140845.55677335148 MeV3
# number density is 140845.55677335447 MeV3
# number density is 140845.5567733515 MeV3
# number density is 140845.55677335188 MeV3
# number density is 140845.55677335308 MeV3
# number density is 140845.55677335308 MeV3
# number density is 140845.5567733552 MeV3
# number density is 140845.55677335017 MeV3
# number density is 140845.55677335197 MeV3
# number density is 140845.55677334985 MeV3
# number density is 140845.55677334865 MeV3
# number density is 140845.55677334865 MeV3
# number density is 140845.5567733481 MeV3
# number density is 140845.55677334234 MeV3
# number density is 140845.55677333733 MeV3
# number density is 140845.55677333713 MeV3
# number density is 140845.55677333486 MeV3
# number density is 140845.55677333486 MeV3
# number density is 140845.55677329938 MeV3
# number density is 140845.5567732831 MeV3
# number density is 140845.55677318707 MeV3
# number density is 140845.55677317237 MeV3
# number density is 140845.5567731542 MeV3
# number density is 140845.5567731542 MeV3
# number density is 140845.55677279673 MeV3
# number density is 140845.55677261614 MeV3
# number density is 140845.5567717164 MeV3
# number density is 140845.55677155533 MeV3
# number density is 140845.5567713558 MeV3
# number density is 140845.5567713558 MeV3
# number density is 140845.55676776043 MeV3
# number density is 140845.55676596542 MeV3
# number density is 140845.55675698002 MeV3
# number density is 140845.55675538187 MeV3
# number density is 140845.5567533818 MeV3
# number density is 140845.5567533818 MeV3
# number density is 140845.5567174378 MeV3
# number density is 140845.5566994641 MeV3
# number density is 140845.55660960404 MeV3
# number density is 140845.55659362834 MeV3
# number density is 140845.55657365732 MeV3
# number density is 140845.55657365732 MeV3
# number density is 140845.5562142054 MeV3
# number density is 140845.55603447196 MeV3
# number density is 140845.55513578033 MeV3
# number density is 140845.5549760095 MeV3
# number density is 140845.55477628688 MeV3
# number density is 140845.5547762898 MeV3
# number density is 140845.55118132953 MeV3
# number density is 140845.54938285737 MeV3
# number density is 140845.54038936383 MeV3
# number density is 140845.53878991754 MeV3
# number density is 140845.53679039807 MeV3
# number density is 140845.5367904312 MeV3
# number density is 140845.50079658726 MeV3
# number density is 140845.48270080666 MeV3
# number density is 140845.39209503419 MeV3
# number density is 140845.37590655207 MeV3
# number density is 140845.35568044265 MeV3
# number density is 140845.35571483086 MeV3
# number density is 140844.99135055853 MeV3
# number density is 140844.7998969467 MeV3
# number density is 140843.81607922073 MeV3
# number density is 140843.61357971764 MeV3
# number density is 140843.39048891974 MeV3
# number density is 140843.42325924087 MeV3
# number density is 140839.33704123544 MeV3
# number density is 140836.75908101242 MeV3
# number density is 140812.3531376655 MeV3
# number density is 140792.77237490538 MeV3
# number density is 140789.89702048723 MeV3
# number density is 140811.93123205117 MeV3
# number density is 140778.43920446353 MeV3
# number density is 140756.93253840707 MeV3
# number density is 140391.65173325725 MeV3
# number density is 139977.91429500125 MeV3
# number density is 139963.05307838233 MeV3
# number density is 140473.56262938422 MeV3
# number density is 140280.54814827934 MeV3
# number density is 140157.72632734754 MeV3
# number density is 138837.48253406768 MeV3
# number density is 137652.8048886315 MeV3
# number density is 137523.78817831443 MeV3
# number density is 138903.11613511242 MeV3
# number density is 138179.05163319662 MeV3
# number density is 137733.42820918327 MeV3
# number density is 133941.8329998406 MeV3
# number density is 131149.12188371393 MeV3
# number density is 130635.03939853961 MeV3
# number density is 133696.5631041681 MeV3
# number density is 131677.51850114582 MeV3
# number density is 130495.96680950343 MeV3
# number density is 121941.49329144171 MeV3
# number density is 116738.19640535039 MeV3
# number density is 115331.45248916176 MeV3
# number density is 120668.23679622971 MeV3
# number density is 116327.67148515052 MeV3
# number density is 113982.99721274276 MeV3
# number density is 99000.7217360927 MeV3
# number density is 91631.87367092323 MeV3
# number density is 88845.2725084926 MeV3
# number density is 95810.15780610421 MeV3
# number density is 88671.07216572177 MeV3
# number density is 85305.55125803156 MeV3
# number density is 65598.06735706252 MeV3
# number density is 58139.01067419065 MeV3
# number density is 54302.69968416938 MeV3
# number density is 60553.348968414255 MeV3
# number density is 51802.3427931945 MeV3
# number density is 48631.150694621974 MeV3
# number density is 28435.803959158486 MeV3
# number density is 18493.60742606714 MeV3
# number density is 13144.455183509988 MeV3
# number density is 24953.078847977096 MeV3
# number density is 53451.138110996224 MeV3
# number density is 50675.54689317943 MeV3
# number density is 34430.286618236285 MeV3
# number density is 28968.68253518358 MeV3
# number density is 25830.976825694663 MeV3
# number density is 30357.8997274516 MeV3
# number density is 24950.425777899123 MeV3
# number density is 23326.126347789865 MeV3
# number density is 10452.869550114576 MeV3
# Distance from center is 20.082546921721253 km, w/ find_pressure 0.0 MeV4 and p -5632.719909030988.
# Distance from center is 20.526493523055915 km, w/ find_pressure 0.0 MeV4 and p -11132.944315893212.
# number density is 9287.477780939766 MeV3
# number density is 26542.59060781943 MeV3
# number density is 25162.912823452985 MeV3
# number density is 16706.623817598756 MeV3
# number density is 13351.133018161423 MeV3
# number density is 11608.740066901652 MeV3
# number density is 14882.732483432284 MeV3
# number density is 12192.20214143565 MeV3
# number density is 11402.129692327113 MeV3
# number density is 4722.425191783119 MeV3
# Distance from center is 21.958151832117572 km, w/ find_pressure 0.0 MeV4 and p -2886.897781253425.
# Distance from center is 22.277397580416025 km, w/ find_pressure 0.0 MeV4 and p -4177.2859272980895.
# number density is 4830.726129038042 MeV3
# number density is 12723.174255518856 MeV3
# number density is 11997.304283104848 MeV3
# number density is 7066.569403910959 MeV3
# number density is 4103.571611490617 MeV3
# number density is 2484.795570226279 MeV3
# number density is 6423.038195548156 MeV3
# number density is 13145.51388199364 MeV3
# number density is 12504.071398220363 MeV3
# number density is 8626.14359964318 MeV3
# number density is 7162.217227817821 MeV3
# number density is 6378.434961067973 MeV3
# number density is 7736.491964854391 MeV3
# number density is 6473.549664967732 MeV3
# number density is 6071.641199447145 MeV3
# number density is 3034.0464512645794 MeV3
# Distance from center is 22.990734827741395 km, w/ find_pressure 0.0 MeV4 and p -180.1136838638804.
# Distance from center is 23.201708297271477 km, w/ find_pressure 0.0 MeV4 and p -869.5157705369038.
# number density is 2496.147313784609 MeV3
# number density is 6876.4496097493275 MeV3
# number density is 6551.1242990896535 MeV3
# number density is 4612.867696842062 MeV3
# number density is 3920.1194877444573 MeV3
# number density is 3530.1768488660136 MeV3
# number density is 4139.352098018053 MeV3
# number density is 3492.7750546532943 MeV3
# number density is 3278.3766391253266 MeV3
# number density is 1728.624084404474 MeV3
# number density is 376.17867785973743 MeV3
# Distance from center is 23.937986652849688 km, w/ find_pressure 0.0 MeV4 and p -173.2940119756422.
# number density is 1504.516969035228 MeV3
# number density is 940.486257116234 MeV3
# number density is 899.2518336911162 MeV3
# Distance from center is 25.24461933537573 km, w/ find_pressure 0.0 MeV4 and p -413.357596303323.
# Distance from center is 25.38980074454529 km, w/ find_pressure 0.0 MeV4 and p -1272.45962200167.
# Distance from center is 25.57127750600724 km, w/ find_pressure 0.0 MeV4 and p -1138.767426075161.
# number density is 253.4075828989159 MeV3
# number density is 1202.1022495829798 MeV3
# number density is 1114.6528931858024 MeV3
# number density is 221.81596023754358 MeV3
# Distance from center is 24.772221199655867 km, w/ find_pressure 0.0 MeV4 and p -162.35988367774075.
# Distance from center is 24.876500518006637 km, w/ find_pressure 0.0 MeV4 and p -142.71438186017258.
# number density is 587.8441467053783 MeV3
# number density is 1321.9730657909013 MeV3
# number density is 1253.118533175203 MeV3
# number density is 830.6282463605125 MeV3
# number density is 658.4270780246729 MeV3
# number density is 564.9867453526135 MeV3
# number density is 735.9311934866987 MeV3
# number density is 595.0445369939507 MeV3
# number density is 552.0871791683973 MeV3
# number density is 160.9970659131554 MeV3
# Distance from center is 25.03973982668994 km, w/ find_pressure 0.0 MeV4 and p -36.09550868593746.
# Distance from center is 25.104548836915836 km, w/ find_pressure 0.0 MeV4 and p -37.39995519345047.
# number density is 248.6364893151403 MeV3
# number density is 630.4622853868593 MeV3
# number density is 592.7737061941674 MeV3
# number density is 341.23939887162817 MeV3
# number density is 192.5394273694186 MeV3
# number density is 98.19944250708788 MeV3
# number density is 304.6444924787051 MeV3
# number density is 657.2266744541325 MeV3
# number density is 626.110349727466 MeV3
# number density is 444.2144653052675 MeV3
# number density is 383.96788909880206 MeV3
# number density is 346.6161757456565 MeV3
# number density is 395.41282320279487 MeV3
# number density is 331.91326126911576 MeV3
# number density is 310.23408550289025 MeV3
# number density is 153.00030669935424 MeV3
# Distance from center is 25.155952517709448 km, w/ find_pressure 0.0 MeV4 and p -0.8528069175813329.
# Distance from center is 25.193286916111017 km, w/ find_pressure 0.0 MeV4 and p -6.1126533635882225.
# number density is 116.45729322457031 MeV3
# number density is 353.47091244553144 MeV3
# number density is 336.77548152474884 MeV3
# number density is 239.55491458204028 MeV3
# number density is 207.89887000442073 MeV3
# number density is 187.910226050416 MeV3
# number density is 213.03911813181276 MeV3
# number density is 178.8633241116767 MeV3
# number density is 167.1270774590005 MeV3
# number density is 82.3556041473042 MeV3
# Distance from center is 25.284803174572676 km, w/ find_pressure 0.0 MeV4 and p -0.2821332474861844.
# Distance from center is 25.309951753635957 km, w/ find_pressure 0.0 MeV4 and p -2.174079002249808.
# number density is 62.121951602323925 MeV3
# number density is 190.54381989457102 MeV3
# number density is 181.5501175751258 MeV3
# number density is 129.29829524067011 MeV3
# number density is 112.45939068557938 MeV3
# number density is 101.70293854392136 MeV3
# number density is 114.9029374820646 MeV3
# number density is 96.45237956081317 MeV3
# number density is 90.09626660675063 MeV3
# number density is 44.24685195376178 MeV3
# Distance from center is 25.37063290692202 km, w/ find_pressure 0.0 MeV4 and p -0.10682695359183114.
# Distance from center is 25.38751634014882 km, w/ find_pressure 0.0 MeV4 and p -0.7833854591865466.
# number density is 33.245073106668 MeV3
# number density is 102.77179139430342 MeV3
# number density is 97.91105884166933 MeV3
# number density is 69.69100048249396 MeV3
# number density is 60.626014121831496 MeV3
# number density is 54.806746867395674 MeV3
# number density is 61.88469434578457 MeV3
# number density is 51.89626383122409 MeV3
# number density is 48.455501245226685 MeV3
# number density is 23.559346183842422 MeV3
# Distance from center is 25.428053433706 km, w/ find_pressure 0.0 MeV4 and p -0.050548203629848576.
# Distance from center is 25.43937625680002 km, w/ find_pressure 0.0 MeV4 and p -0.28852898214516287.
# number density is 17.7723509770175 MeV3
# number density is 55.298650870254555 MeV3
# number density is 52.66138980827275 MeV3
# number density is 37.321579200859205 MeV3
# number density is 32.35243858662218 MeV3
# number density is 29.177726569178763 MeV3
# number density is 33.09862200029039 MeV3
# number density is 27.670344796459894 MeV3
# number density is 25.81207922340325 MeV3
# number density is 12.18225344674607 MeV3
# Distance from center is 25.466930510988274 km, w/ find_pressure 0.0 MeV4 and p -0.03190313620959928.
# Distance from center is 25.474545785225594 km, w/ find_pressure 0.0 MeV4 and p -0.11147783318099236.
# number density is 9.418501546902252 MeV3
# number density is 29.46935783688336 MeV3
# number density is 28.02617794974807 MeV3
# number density is 19.558289198130865 MeV3
# number density is 16.7051301521701 MeV3
# number density is 14.931562822814008 MeV3
# number density is 17.291102572552763 MeV3
# number density is 14.31232663111796 MeV3
# number density is 13.317307919143785 MeV3
# number density is 5.648936929107027 MeV3
# Distance from center is 25.494278051522954 km, w/ find_pressure 0.0 MeV4 and p -0.026710452862439726.
# Distance from center is 25.49947038884256 km, w/ find_pressure 0.0 MeV4 and p -0.048141476796110694.
# number density is 4.921191622575753 MeV3
# number density is 15.14320594110272 MeV3
# number density is 14.319575675049599 MeV3
# number density is 9.262563420543444 MeV3
# number density is 7.177371708822092 MeV3
# number density is 6.00250868528385 MeV3
# number density is 8.112854886865136 MeV3
# number density is 6.393820090942397 MeV3
# number density is 5.892573762627736 MeV3
# Distance from center is 25.514461261931963 km, w/ find_pressure 0.0 MeV4 and p -0.000757753010087403.
# Distance from center is 25.51750925743645 km, w/ find_pressure 0.0 MeV4 and p -0.03683958100470763.
# Distance from center is 25.52131925181706 km, w/ find_pressure 0.0 MeV4 and p -0.024687059555841523.
# number density is 4.06993760977179 MeV3
# number density is 7.262473370513862 MeV3
# number density is 6.919872508395603 MeV3
# number density is 4.937117138391557 MeV3
# number density is 4.309375944566747 MeV3
# number density is 3.9001535833918117 MeV3
# number density is 4.3813832402580655 MeV3
# number density is 3.6756999635339613 MeV3
# number density is 3.4313621003153307 MeV3
# number density is 1.6711322214627444 MeV3
# Distance from center is 25.520350218437766 km, w/ find_pressure 0.0 MeV4 and p -0.0005454196376766911.
# Distance from center is 25.522310272322834 km, w/ find_pressure 0.0 MeV4 and p -0.003459728081390792.
# number density is 1.248839536465871 MeV3
# number density is 3.913957347713004 MeV3
# number density is 3.7264469120125225 MeV3
# number density is 2.635844405712944 MeV3
# number density is 2.2826648980113124 MeV3
# number density is 2.056334716706541 MeV3
# number density is 2.334944656356722 MeV3
# number density is 1.9481992976961846 MeV3
# number density is 1.8160956956142396 MeV3
# number density is 0.8396936917330773 MeV3
# Distance from center is 25.52717741894109 km, w/ find_pressure 0.0 MeV4 and p -0.0004913907505236532.
# Distance from center is 25.528501397269554 km, w/ find_pressure 0.0 MeV4 and p -0.0014167632332145567.
# number density is 0.6592949495129905 MeV3
# number density is 2.067825950113511 MeV3
# number density is 1.9626776319600776 MeV3
# number density is 1.3374181704912675 MeV3
# number density is 1.1136966943511521 MeV3
# number density is 0.9795599970478964 MeV3
# number density is 1.1772495827248024 MeV3
# number density is 0.9592464643949588 MeV3
# number density is 0.889270318653958 MeV3
# number density is 0.29836880673819555 MeV3
# Distance from center is 25.53242199714252 km, w/ find_pressure 0.0 MeV4 and p -0.0006131259912311175.
# Distance from center is 25.533353550367764 km, w/ find_pressure 0.0 MeV4 and p -0.0007237990945118083.
# number density is 0.36070009567588107 MeV3
# number density is 0.14109251196913875 MeV3
# number density is 0.19393984838745024 MeV3
# Distance from center is 25.541695416592393 km, w/ find_pressure 0.0 MeV4 and p -0.0017314303786633675.
# Distance from center is 25.542622290617356 km, w/ find_pressure 0.0 MeV4 and p -0.005071702179505035.
# Distance from center is 25.543780883148546 km, w/ find_pressure 0.0 MeV4 and p -0.004672510816254003.
# Distance from center is 25.543780883148546 km, w/ find_pressure 0.0 MeV4 and p -0.00011736295438045312.
# Mass is 2.01e+59 MeV.
# Solved TOV
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.9260844116 MeV3
# number density is 162168.92608441357 MeV3
# number density is 162168.92608441357 MeV3
# number density is 162168.9260844111 MeV3
# number density is 162168.9260844111 MeV3
# number density is 162168.9260844111 MeV3
# number density is 162168.9260844104 MeV3
# number density is 162168.92608441346 MeV3
# number density is 162168.92608440973 MeV3
# number density is 162168.9260844119 MeV3
# number density is 162168.9260844087 MeV3
# number density is 162168.9260844087 MeV3
# number density is 162168.92608441028 MeV3
# number density is 162168.92608441412 MeV3
# number density is 162168.9260844086 MeV3
# number density is 162168.92608440865 MeV3
# number density is 162168.92608441654 MeV3
# number density is 162168.92608441654 MeV3
# number density is 162168.9260844064 MeV3
# number density is 162168.92608440315 MeV3
# number density is 162168.92608439215 MeV3
# number density is 162168.92608438636 MeV3
# number density is 162168.92608438552 MeV3
# number density is 162168.92608438552 MeV3
# number density is 162168.92608434553 MeV3
# number density is 162168.9260843259 MeV3
# number density is 162168.92608421514 MeV3
# number density is 162168.926084195 MeV3
# number density is 162168.9260841701 MeV3
# number density is 162168.9260841701 MeV3
# number density is 162168.92608373336 MeV3
# number density is 162168.9260835151 MeV3
# number density is 162168.92608242558 MeV3
# number density is 162168.92608223174 MeV3
# number density is 162168.92608199097 MeV3
# number density is 162168.92608199097 MeV3
# number density is 162168.92607762624 MeV3
# number density is 162168.92607544496 MeV3
# number density is 162168.92606454785 MeV3
# number density is 162168.9260626081 MeV3
# number density is 162168.92606017998 MeV3
# number density is 162168.92606017998 MeV3
# number density is 162168.92601657688 MeV3
# number density is 162168.9259947752 MeV3
# number density is 162168.92588574885 MeV3
# number density is 162168.92586637224 MeV3
# number density is 162168.9258421444 MeV3
# number density is 162168.9258421444 MeV3
# number density is 162168.92540606315 MeV3
# number density is 162168.92518800267 MeV3
# number density is 162168.9240977109 MeV3
# number density is 162168.92390387665 MeV3
# number density is 162168.92366157644 MeV3
# number density is 162168.92366157944 MeV3
# number density is 162168.91930018197 MeV3
# number density is 162168.9171182782 MeV3
# number density is 162168.90620738268 MeV3
# number density is 162168.9042669385 MeV3
# number density is 162168.90184112618 MeV3
# number density is 162168.90184116713 MeV3
# number density is 162168.85817349318 MeV3
# number density is 162168.83621973012 MeV3
# number density is 162168.72629699358 MeV3
# number density is 162168.70665719817 MeV3
# number density is 162168.68211892142 MeV3
# number density is 162168.68216056318 MeV3
# number density is 162168.24011445954 MeV3
# number density is 162168.0078419644 MeV3
# number density is 162166.81430026013 MeV3
# number density is 162166.56867592694 MeV3
# number density is 162166.29801758874 MeV3
# number density is 162166.33770930654 MeV3
# number density is 162161.3803163613 MeV3
# number density is 162158.25183366117 MeV3
# number density is 162128.65877270646 MeV3
# number density is 162104.93529007465 MeV3
# number density is 162101.44352174053 MeV3
# number density is 162128.13185030318 MeV3
# number density is 162087.9139786512 MeV3
# number density is 162062.05680140582 MeV3
# number density is 161628.46668133227 MeV3
# number density is 161139.66693610366 MeV3
# number density is 161121.4383112007 MeV3
# number density is 161723.92586700115 MeV3
# number density is 161494.61236675052 MeV3
# number density is 161348.7152469889 MeV3
# number density is 159791.2232178207 MeV3
# number density is 158400.49922458525 MeV3
# number density is 158246.61629443805 MeV3
# number density is 159863.58901485405 MeV3
# number density is 159009.22219991262 MeV3
# number density is 158483.7349691284 MeV3
# number density is 154032.81716394084 MeV3
# number density is 150769.92501034413 MeV3
# number density is 150162.73990632236 MeV3
# number density is 153734.0375199782 MeV3
# number density is 151364.7671192164 MeV3
# number density is 149979.89603833275 MeV3
# number density is 139986.395992661 MeV3
# number density is 133936.34484968876 MeV3
# number density is 132286.64548130584 MeV3
# number density is 138481.07869133892 MeV3
# number density is 133415.52913871696 MeV3
# number density is 130685.04442783474 MeV3
# number density is 113282.20305297164 MeV3
# number density is 104770.03316489614 MeV3
# number density is 101526.27358049426 MeV3
# number density is 109553.17636985866 MeV3
# number density is 101271.51593089486 MeV3
# number density is 97382.46865585694 MeV3
# number density is 74633.00708469034 MeV3
# number density is 66064.2147522065 MeV3
# number density is 61637.38314543211 MeV3
# number density is 68803.7825602375 MeV3
# number density is 58730.74325069382 MeV3
# number density is 55109.96191376199 MeV3
# number density is 31889.017072135175 MeV3
# number density is 20113.987406776014 MeV3
# number density is 13645.660616992573 MeV3
# number density is 28033.4497930112 MeV3
# number density is 60851.25615868024 MeV3
# number density is 57735.77986365218 MeV3
# number density is 39584.48316623827 MeV3
# number density is 33617.53209247503 MeV3
# number density is 30129.795970500767 MeV3
# number density is 34953.51334580562 MeV3
# number density is 28884.258463792008 MeV3
# number density is 27029.528066884854 MeV3
# number density is 12750.539653289421 MeV3
# Distance from center is 19.491641420669268 km, w/ find_pressure 0.0 MeV4 and p -4489.83774443742.
# Distance from center is 19.91440789990221 km, w/ find_pressure 0.0 MeV4 and p -12270.365021870923.
# number density is 10708.739665791978 MeV3
# number density is 30811.976962997964 MeV3
# number density is 29280.599530366515 MeV3
# number density is 20115.709049627247 MeV3
# number density is 16817.943574202167 MeV3
# number density is 15005.392924898257 MeV3
# number density is 17952.735227138983 MeV3
# number density is 14970.467482573062 MeV3
# number density is 14042.901728145876 MeV3
# number density is 6971.115858652576 MeV3
# Distance from center is 21.112449337103453 km, w/ find_pressure 0.0 MeV4 and p -854.9815918776985.
# Distance from center is 21.406739910650373 km, w/ find_pressure 0.0 MeV4 and p -3590.3152791982757.
# number density is 5796.510374139678 MeV3
# number density is 15917.094797786085 MeV3
# number density is 15157.897220464914 MeV3
# number density is 10621.517885703466 MeV3
# number density is 8989.530364551238 MeV3
# number density is 8087.429158542263 MeV3
# number density is 9536.212146084032 MeV3
# number density is 8044.476740828703 MeV3
# number density is 7558.731550181283 MeV3
# number density is 4033.199833365072 MeV3
# number density is 1027.726122541218 MeV3
# Distance from center is 22.443286153331997 km, w/ find_pressure 0.0 MeV4 and p -597.4308181199449.
# number density is 3592.810813280543 MeV3
# number density is 2702.4665501923328 MeV3
# number density is 2500.8418624216633 MeV3
# Distance from center is 23.788958877296977 km, w/ find_pressure 0.0 MeV4 and p -293.1264762172698.
# Distance from center is 23.938478068848642 km, w/ find_pressure 0.0 MeV4 and p -1603.6150679107204.
# Distance from center is 24.125377058288223 km, w/ find_pressure 0.0 MeV4 and p -1263.3257347471235.
# number density is 1601.3544647520346 MeV3
# number density is 3148.375751458457 MeV3
# number density is 2983.879838379405 MeV3
# number density is 1962.009210187375 MeV3
# number density is 1525.6285693641362 MeV3
# number density is 1297.2834033101371 MeV3
# number density is 1745.8812567905659 MeV3
# number density is 1411.9183997756222 MeV3
# number density is 1311.6820301344276 MeV3
# number density is 390.9584187965634 MeV3
# Distance from center is 24.104213987318477 km, w/ find_pressure 0.0 MeV4 and p -151.78187726336284.
# Distance from center is 24.2019156246118 km, w/ find_pressure 0.0 MeV4 and p -158.29960759379742.
# number density is 595.9042401094946 MeV3
# number density is 1491.5843565884272 MeV3
# number density is 1402.3502068086814 MeV3
# number density is 797.1148332439709 MeV3
# number density is 416.10080667307545 MeV3
# number density is 152.50039853739563 MeV3
# number density is 721.1467763577191 MeV3
# number density is 1566.3645853481753 MeV3
# number density is 1495.1535164112424 MeV3
# number density is 1082.8729408008417 MeV3
# number density is 952.0368755617856 MeV3
# number density is 868.7946884144751 MeV3
# number density is 969.4500703961523 MeV3
# number density is 825.3021749365453 MeV3
# number density is 774.7156101843493 MeV3
# number density is 428.1406499322392 MeV3
# number density is 195.31263721376334 MeV3
# Distance from center is 24.298779433587416 km, w/ find_pressure 0.0 MeV4 and p -2.1333352482964756.
# number density is 392.4415477099882 MeV3
# number density is 876.9221550024748 MeV3
# number density is 839.2955241000686 MeV3
# number density is 625.942922961503 MeV3
# number density is 564.3046563223324 MeV3
# number density is 521.421373715059 MeV3
# number density is 562.9956438707791 MeV3
# number density is 486.7199812142938 MeV3
# number density is 458.7127522288817 MeV3
# number density is 278.3515817970676 MeV3
# number density is 187.298240243419 MeV3
# number density is 136.8815247386713 MeV3
# number density is 245.3901740564698 MeV3
# number density is 496.7850435697358 MeV3
# number density is 471.2467036383875 MeV3
# number density is 317.173572037239 MeV3
# number density is 258.55333637715466 MeV3
# number density is 225.135110796147 MeV3
# number density is 280.03197118325926 MeV3
# number density is 227.43781670209256 MeV3
# number density is 210.94563846339344 MeV3
# number density is 67.13138904175898 MeV3
# Distance from center is 24.656959858284036 km, w/ find_pressure 0.0 MeV4 and p -6.273292675579938.
# Distance from center is 24.687956603806075 km, w/ find_pressure 0.0 MeV4 and p -6.977580181988042.
# number density is 89.59730275027016 MeV3
# number density is 233.9986355693149 MeV3
# number density is 218.4006112757564 MeV3
# number density is 103.09397646712394 MeV3
# Distance from center is 24.627914936611564 km, w/ find_pressure 0.0 MeV4 and p -1.205468886072829.
# Distance from center is 24.65528106692454 km, w/ find_pressure 0.0 MeV4 and p -3.9534451927501912.
# number density is 81.08226679949507 MeV3
# number density is 249.0409812265065 MeV3
# number density is 236.8162058650228 MeV3
# number density is 164.7423102482032 MeV3
# number density is 139.94007977960607 MeV3
# number density is 124.84717133695013 MeV3
# number density is 145.8368341193708 MeV3
# number density is 120.69330410681242 MeV3
# number density is 112.35135780897276 MeV3
# number density is 47.73446092238764 MeV3
# Distance from center is 24.728322369743733 km, w/ find_pressure 0.0 MeV4 and p -0.9473720792464917.
# Distance from center is 24.74710686831056 km, w/ find_pressure 0.0 MeV4 and p -1.6887920573687918.
# number density is 41.99957996613824 MeV3
# number density is 127.62272638777709 MeV3
# number density is 120.67985431241844 MeV3
# ...
# number density is 1512560.9327167948 MeV3
# number density is 1136673.1856010882 MeV3
# number density is 985869.3663312274 MeV3
# number density is 1407153.7871887565 MeV3
# number density is 1198576.216234006 MeV3
# number density is 1134138.6449955604 MeV3
# number density is 661202.0610873622 MeV3
# number density is 301221.56928637606 MeV3
# number density is 79800.5635143747 MeV3
# number density is 634220.9524698074 MeV3
# number density is 1256354.7463367558 MeV3
# number density is 1201701.3168525796 MeV3
# number density is 873071.60896285 MeV3
# number density is 750002.5897986632 MeV3
# number density is 687510.6949907065 MeV3
# number density is 799855.5549291573 MeV3
# number density is 695882.0311410392 MeV3
# number density is 660333.4098738437 MeV3
# number density is 427367.326703535 MeV3
# number density is 307347.5412512884 MeV3
# number density is 253506.93929002824 MeV3
# number density is 390793.2872926908 MeV3
# number density is 320521.46486638393 MeV3
# number density is 299951.261509658 MeV3
# number density is 120235.10037750877 MeV3
# Distance from center is 5.142427939499688 km, w/ find_pressure 0.0 MeV4 and p -794364.726603548.
# Distance from center is 5.1767155247498415 km, w/ find_pressure 0.0 MeV4 and p -1042640.677375515.
# number density is 133124.27379302395 MeV3
# number density is 92729.25557795569 MeV3
# number density is 86336.77697167803 MeV3
# Distance from center is 5.407162930556787 km, w/ find_pressure 0.0 MeV4 and p -344713.05738973885.
# Distance from center is 5.43276819786867 km, w/ find_pressure 0.0 MeV4 and p -1213326.3362941553.
# Distance from center is 5.464774782008523 km, w/ find_pressure 0.0 MeV4 and p -1041659.5283334304.
# number density is 44907.01716625032 MeV3
# number density is 112864.90631464488 MeV3
# number density is 105993.62525980618 MeV3
# number density is 57452.45566553614 MeV3
# number density is 20341.553937118624 MeV3
# Distance from center is 5.329688481997903 km, w/ find_pressure 0.0 MeV4 and p -29940.49473839812.
# number density is 52052.27158135477 MeV3
# number density is 118562.44348431096 MeV3
# number density is 112936.79679244527 MeV3
# number density is 79640.00774551545 MeV3
# number density is 67959.80427384192 MeV3
# number density is 61163.911249392084 MeV3
# number density is 71225.75522361507 MeV3
# number density is 59897.2929587238 MeV3
# number density is 56082.024980370516 MeV3
# number density is 28346.487066092308 MeV3
# Distance from center is 5.387583641543858 km, w/ find_pressure 0.0 MeV4 and p -2032.0486974685628.
# Distance from center is 5.399987648414094 km, w/ find_pressure 0.0 MeV4 and p -32304.71204506373.
# number density is 21899.92394346305 MeV3
# number density is 63717.44812193644 MeV3
# number density is 60756.50122846377 MeV3
# number density is 43492.07312235402 MeV3
# number density is 37821.411087773944 MeV3
# number density is 34312.444776470365 MeV3
# number density is 38859.59334436601 MeV3
# number density is 32861.177705232905 MeV3
# number density is 30788.460202307942 MeV3
# number density is 16191.638960400996 MeV3
# number density is 4501.388304828133 MeV3
# Distance from center is 5.439192687106424 km, w/ find_pressure 0.0 MeV4 and p -6170.398220167714.
# number density is 14051.859996077725 MeV3
# number density is 33806.784374056224 MeV3
# number density is 31930.16439303486 MeV3
# number density is 20082.81554194434 MeV3
# number density is 14600.72271028717 MeV3
# number density is 11655.571573685596 MeV3
# number density is 17715.540040338426 MeV3
# number density is 14039.590708292293 MeV3
# number density is 12970.491900946503 MeV3
# number density is 1081.119962321699 MeV3
# Distance from center is 5.4819879921103745 km, w/ find_pressure 0.0 MeV4 and p -12013.325068202437.
# Distance from center is 5.488753699366177 km, w/ find_pressure 0.0 MeV4 and p -8981.905098538162.
# number density is 8035.697967353082 MeV3
# number density is 15777.337641603417 MeV3
# number density is 15011.463543188374 MeV3
# number density is 10511.228145575866 MeV3
# number density is 8983.82995846866 MeV3
# number density is 8047.662617512236 MeV3
# number density is 9320.342082124716 MeV3
# number density is 7749.234910786594 MeV3
# number density is 7222.461331051326 MeV3
# number density is 3236.4594020004984 MeV3
# Distance from center is 5.490715594420148 km, w/ find_pressure 0.0 MeV4 and p -697.417342886527.
# Distance from center is 5.494412845029337 km, w/ find_pressure 0.0 MeV4 and p -1549.4206518398241.
# number density is 2680.9643413036088 MeV3
# number density is 8228.797563831362 MeV3
# number density is 7804.606862758971 MeV3
# number density is 5255.632807961665 MeV3
# number density is 4300.469640727666 MeV3
# number density is 3746.9464741951847 MeV3
# number density is 4629.935626756581 MeV3
# number density is 3753.0936479806032 MeV3
# number density is 3477.553349665029 MeV3
# number density is 1054.9253618367318 MeV3
# Distance from center is 5.505625493159643 km, w/ find_pressure 0.0 MeV4 and p -711.2828762494219.
# Distance from center is 5.508242428666291 km, w/ find_pressure 0.0 MeV4 and p -765.6228681649309.
# number density is 1496.1223274130734 MeV3
# number density is 3926.707630743565 MeV3
# number density is 3677.7307382616523 MeV3
# number density is 1962.410388855993 MeV3
# number density is 727.400408844303 MeV3
# Distance from center is 5.50384159459587 km, w/ find_pressure 0.0 MeV4 and p -113.12254705950181.
# number density is 1736.1194282588338 MeV3
# number density is 4137.002392385082 MeV3
# number density is 3939.764074625757 MeV3
# number density is 2792.2387564482356 MeV3
# number density is 2419.9174186725063 MeV3
# number density is 2182.556918573784 MeV3
# number density is 2476.912762010222 MeV3
# number density is 2071.2524110488234 MeV3
# number density is 1932.387460366957 MeV3
# number density is 914.7832849488942 MeV3
# Distance from center is 5.5104639487800435 km, w/ find_pressure 0.0 MeV4 and p -40.719687736139235.
# Distance from center is 5.511980062878489 km, w/ find_pressure 0.0 MeV4 and p -146.84418930449579.
# number density is 706.3953525233163 MeV3
# number density is 2206.0104134322924 MeV3
# number density is 2098.258611234392 MeV3
# number density is 1466.4685582813163 MeV3
# number density is 1254.201330607697 MeV3
# number density is 1122.079791283103 MeV3
# number density is 1297.0384181210206 MeV3
# number density is 1074.7952463412676 MeV3
# number density is 1000.3786456253691 MeV3
# number density is 430.09857114205647 MeV3
# Distance from center is 5.515888037125289 km, w/ find_pressure 0.0 MeV4 and p -33.1796117489406.
# Distance from center is 5.516920566603689 km, w/ find_pressure 0.0 MeV4 and p -62.66237334892497.
# number density is 368.845476639665 MeV3
# number density is 1138.7334776602415 MeV3
# number density is 1077.706737315524 MeV3
# number density is 705.7088633396403 MeV3
# number density is 557.1309638682792 MeV3
# number density is 472.6817901436374 MeV3
# number density is 618.7708029995028 MeV3
# number density is 491.67126914889525 MeV3
# number density is 453.72058284746106 MeV3
# number density is 53.03102063796771 MeV3
# Distance from center is 5.520356613547054 km, w/ find_pressure 0.0 MeV4 and p -41.83727383988523.
# Distance from center is 5.521105367208758 km, w/ find_pressure 0.0 MeV4 and p -32.59981792837672.
# number density is 264.51963018669255 MeV3
# number density is 549.7773752847079 MeV3
# number density is 522.4393323458045 MeV3
# number density is 361.2343417019716 MeV3
# number density is 305.68114914568775 MeV3
# number density is 271.6247530301222 MeV3
# number density is 318.7584523557018 MeV3
# number density is 262.2233171699558 MeV3
# number density is 243.6198904176695 MeV3
# number density is 95.39078903467554 MeV3
# Distance from center is 5.521517613626222 km, w/ find_pressure 0.0 MeV4 and p -4.766123316549795.
# Distance from center is 5.521938262412856 km, w/ find_pressure 0.0 MeV4 and p -6.996544992637638.
# number density is 92.28444438700801 MeV3
# number density is 274.0115410150857 MeV3
# number density is 257.5682415354038 MeV3
# number density is 150.27631421981812 MeV3
# number density is 92.0197854899288 MeV3
# number density is 56.502726261523094 MeV3
# number density is 132.09767437785518 MeV3
# number density is 283.6302812031623 MeV3
# number density is 269.66119931090867 MeV3
# number density is 187.6070996167289 MeV3
# number density is 159.81829981228924 MeV3
# number density is 142.57568565411466 MeV3
# number density is 165.69614284501122 MeV3
# number density is 136.82402740000802 MeV3
# number density is 127.22437017187566 MeV3
# number density is 52.36099761865813 MeV3
# Distance from center is 5.522705209694424 km, w/ find_pressure 0.0 MeV4 and p -1.324665956098391.
# Distance from center is 5.522973020656852 km, w/ find_pressure 0.0 MeV4 and p -2.186251647871474.
# number density is 47.29593799728182 MeV3
# number density is 144.29212961316964 MeV3
# number density is 136.18213026377288 MeV3
# number density is 85.53332022622476 MeV3
# number density is 63.00195479589103 MeV3
# number density is 50.41218981540172 MeV3
# number density is 74.78962061940122 MeV3
# number density is 58.6996380373228 MeV3
# number density is 54.0594694501502 MeV3
# Distance from center is 5.523760008849685 km, w/ find_pressure 0.0 MeV4 and p -0.0692455941068939.
# Distance from center is 5.523913438157291 km, w/ find_pressure 0.0 MeV4 and p -1.5692372214799324.
# Distance from center is 5.524105224791797 km, w/ find_pressure 0.0 MeV4 and p -1.0714143430891867.
# number density is 36.99753929618431 MeV3
# number density is 66.86369174924903 MeV3
# number density is 63.67778438019569 MeV3
# number density is 45.18531003260866 MeV3
# number density is 39.251390877203335 MeV3
# number density is 35.42098479025934 MeV3
# number density is 40.0487678406929 MeV3
# number density is 33.47931720870112 MeV3
# number density is 31.22367014142067 MeV3
# number density is 14.707988227009832 MeV3
# Distance from center is 5.524050740535403 km, w/ find_pressure 0.0 MeV4 and p -0.04391515473587948.
# Distance from center is 5.524149069679765 km, w/ find_pressure 0.0 MeV4 and p -0.153483283891098.
# number density is 11.324159832231084 MeV3
# number density is 35.663297224915055 MeV3
# number density is 33.915526299375955 MeV3
# number density is 23.671137487841996 MeV3
# number density is 20.23525372673034 MeV3
# number density is 18.08771357678794 MeV3
# number density is 20.9147188959259 MeV3
# number density is 17.30251086160858 MeV3
# number density is 16.094981075772413 MeV3
# number density is 6.775696802845524 MeV3
# Distance from center is 5.524402172137632 km, w/ find_pressure 0.0 MeV4 and p -0.03781676682640839.
# Distance from center is 5.5244691171233455 km, w/ find_pressure 0.0 MeV4 and p -0.06683988776538241.
# number density is 5.935725606403611 MeV3
# number density is 18.298333607125926 MeV3
# number density is 17.29593591645149 MeV3
# number density is 11.126378612145167 MeV3
# number density is 8.553537340121212 MeV3
# number density is 7.103996030899939 MeV3
# number density is 9.735927247807885 MeV3
# number density is 7.640155171507871 MeV3
# number density is 7.035783076575546 MeV3
# Distance from center is 5.524665860362674 km, w/ find_pressure 0.0 MeV4 and p -0.002368083900631507.
# Distance from center is 5.524705329405181 km, w/ find_pressure 0.0 MeV4 and p -0.05256182701563347.
# Distance from center is 5.524754665708314 km, w/ find_pressure 0.0 MeV4 and p -0.03590626814121223.
# number density is 4.812949614793327 MeV3
# number density is 8.701395031943644 MeV3
# number density is 8.285769085905457 MeV3
# number density is 5.871549431617632 MeV3
# number density is 5.094353507800092 MeV3
# number density is 4.593801026841954 MeV3
# number density is 5.202403874490304 MeV3
# number density is 4.345093035184291 MeV3
# number density is 4.05134987867638 MeV3
# number density is 1.891516288782661 MeV3
# Distance from center is 5.524741525603818 km, w/ find_pressure 0.0 MeV4 and p -0.0016531302940301154.
# Distance from center is 5.5247668718758 km, w/ find_pressure 0.0 MeV4 and p -0.005242665563494411.
# number density is 1.4687862781372139 MeV3
# number density is 4.623803093721882 MeV3
# number density is 4.394156635812721 MeV3
# number density is 3.041522828815841 MeV3
# number density is 2.5777754544646965 MeV3
# number density is 2.292154596807085 MeV3
# number density is 2.6834299223733873 MeV3
# number density is 2.208225997555607 MeV3
# number density is 2.051544177866249 MeV3
# number density is 0.8064134307169287 MeV3
# Distance from center is 5.524835244423749 km, w/ find_pressure 0.0 MeV4 and p -0.0016340415782639256.
# Distance from center is 5.524852684952912 km, w/ find_pressure 0.0 MeV4 and p -0.002422368557143671.
# number density is 0.7743217511026088 MeV3
# number density is 2.3030396564840347 MeV3
# number density is 2.1636740470490867 MeV3
# number density is 1.249396190573006 MeV3
# number density is 0.7396087708339663 MeV3
# number density is 0.417721200832248 MeV3
# number density is 1.1002830520927147 MeV3
# number density is 2.3881648247969367 MeV3
# number density is 2.270628713709184 MeV3
# number density is 1.580691933271091 MeV3
# number density is 1.347759986404571 MeV3
# number density is 1.20280653882517 MeV3
# number density is 1.395933079047616 MeV3
# number density is 1.1529042173795476 MeV3
# number density is 1.0720045810287795 MeV3
# number density is 0.44201846674498635 MeV3
# Distance from center is 5.524884474625119 km, w/ find_pressure 0.0 MeV4 and p -0.00045730984735193464.
# Distance from center is 5.524895577827159 km, w/ find_pressure 0.0 MeV4 and p -0.0007598338042450262.
# number density is 0.3977292014408292 MeV3
# number density is 1.2066941430394913 MeV3
# number density is 1.1361735909436341 MeV3
# number density is 0.6850951192270858 MeV3
# number density is 0.4616025038561855 MeV3
# number density is 0.33379495331547715 MeV3
# number density is 0.5994472714401013 MeV3
# number density is 0.46563862492344915 MeV3
# number density is 0.42822985739260233 MeV3
# Distance from center is 5.524931841009155 km, w/ find_pressure 0.0 MeV4 and p -5.330021548057007e-05.
# Distance from center is 5.524938205287517 km, w/ find_pressure 0.0 MeV4 and p -0.0005673856859728724.
# Distance from center is 5.524946160635469 km, w/ find_pressure 0.0 MeV4 and p -0.00040343307249863744.
# number density is 0.28643766820145944 MeV3
# number density is 0.5222608624555511 MeV3
# number density is 0.4929686485370362 MeV3
# number density is 0.31034309766268164 MeV3
# number density is 0.2296977803731576 MeV3
# number density is 0.18458004242759027 MeV3
# number density is 0.27130795329044494 MeV3
# number density is 0.20986344208965382 MeV3
# number density is 0.1929090059089502 MeV3
# Distance from center is 5.524951547479122 km, w/ find_pressure 0.0 MeV4 and p -1.7607266704480165e-05.
# Distance from center is 5.524955349206295 km, w/ find_pressure 0.0 MeV4 and p -0.00015846992840202367.
# Distance from center is 5.5249601013652585 km, w/ find_pressure 0.0 MeV4 and p -0.0001142786737608802.
# number density is 0.12781542497751952 MeV3
# number density is 0.22843444361484563 MeV3
# number density is 0.213442082868664 MeV3
# number density is 0.1072339172275315 MeV3
# number density is 0.0024674268794296437 MeV3
# Distance from center is 5.524947947913828 km, w/ find_pressure 0.0 MeV4 and p -2.9043751244764394e-05.
# number density is 0.07938019476573607 MeV3
# number density is 0.050174540531830354 MeV3
# number density is 0.047137492591660134 MeV3
# Distance from center is 5.524971095469068 km, w/ find_pressure 0.0 MeV4 and p -2.8350357388850005e-05.
# Distance from center is 5.5249736674196495 km, w/ find_pressure 0.0 MeV4 and p -8.636479613012174e-05.
# Distance from center is 5.524976882357877 km, w/ find_pressure 0.0 MeV4 and p -7.672853439363454e-05.
# number density is 0.012108570000137833 MeV3
# Distance from center is 5.5249836013341636 km, w/ find_pressure 0.0 MeV4 and p -1.5266302052041291e-06.
# number density is 0.004397873447423494 MeV3
# Distance from center is 5.525003758263024 km, w/ find_pressure 0.0 MeV4 and p -3.077851551004156e-05.
# Distance from center is 5.525006744474707 km, w/ find_pressure 0.0 MeV4 and p -9.087702194320182e-05.
# Distance from center is 5.525010477239311 km, w/ find_pressure 0.0 MeV4 and p -8.466820464844749e-05.
# Distance from center is 5.525010477239311 km, w/ find_pressure 0.0 MeV4 and p -2.2944036586552536e-06.
# Mass is 6.05e+59 MeV.
# Solved TOV

# %%
mass = mass * u.solMass
radius = radius * u.km
print(mass, radius)
# Out:
# [0.1688043  0.18011198 0.19203835 0.20471653 0.21706062 0.23203587
#  0.2467516  0.26212677 0.27828093 0.29518835 0.31271175 0.33082797
#  0.34962746 0.36927849 0.38924401 0.40965804 0.43039836 0.45107027
#  0.47275148 0.49403809 0.5158371  0.53605418 0.5572547  0.57663465
#  0.59575569 0.61406717 0.63149883 0.64710767 0.66081191 0.67322671
#  0.68336915 0.69222851 0.69985403 0.70448208 0.7071331  0.70758308
#  0.70543863 0.70182476 0.69570272 0.68836501 0.67865622 0.66779191
#  0.65492375 0.6415112  0.62696307 0.61139486 0.594864   0.57778236
#  0.55991441 0.54279047] solMass [26.28741072 25.5368974  24.89547193 24.35049496 23.50211546 23.11959718
#  22.5303781  21.94300037 21.37652245 20.85205981 20.29643298 19.75845214
#  19.15516597 18.68943609 18.15800931 17.67471011 17.11711071 16.55996672
#  16.15795754 15.67415    15.29737485 14.73843454 14.40985589 13.80400238
#  13.3746383  12.93834705 12.63179573 12.17103336 11.65593895 11.30302818
#  10.83973249 10.45477568 10.09827562  9.77466361  9.36614276  9.01987919
#   8.68774829  8.37300955  8.01558071  7.74259618  7.45810242  7.22353395
#   6.92567168  6.67511282  6.46010203  6.24489839  6.03906358  5.85282415
#   5.69599057  5.52498048] km

# %%
# modified_radius = radius[(mass.value < 10) & (radius.value < 100)]
# modified_mass = mass[(mass.value < 10) & (radius.value < 100)]

# print(modified_mass, modified_radius)

# %%
fig, ax = plt.subplots(figsize = (8, 8))
ax.set_title("Mass vs radius of neutron stars -\nnon-interacting pure neutron Fermi gas", fontsize = 16);
ax.set_xlabel("Radius (km)", fontsize = 16);
ax.set_ylabel("Mass ($\mathrm{M_{\odot}}$)", fontsize = 16);
# ax2.set_ylim(0, 1);
# ax2.set_xlim(0, 25);
# ax.set_ylim(0.3, 0.8);
# ax1.set_ylim(-0.25 * 10 ** 303, 0.01 * 10 ** 304)
# ax1.plot(np.log(mass_density.value), np.log(pressure_list), "o");
ax.plot(radius, mass, "o");

plt.savefig("fermi_mass_radius_plot.pdf", bbox_inches = "tight");

# %%
index = np.where(mass == np.max(mass))
print(f"Maximum mass is {np.max(mass)} and radius is {radius[index]}.")
# Out:
# Maximum mass is 0.7075830818645082 solMass and radius is [9.01987919] km.
